# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-41c2037bf12f1e46d8f08b88a04a8d8f.css" integrity="sha512-dsqgdBtnWun6oxDg9q1xezEyITXQ8QsMdFm+JDoDk6Tzx9AEE1XcUEhWff/M2Jv85ucTVJCjp/2fGbh6Omtrgg==" media="all" rel="stylesheet">
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-294181adec18ed639e160b96b45d17ac.css" integrity="sha512-MRlTIqIyb8caK5+o8llXVntXovciHyAM4qE3kWU2S7SIjAPDxYp4mE0jQp4kP5UYegy+lG9y1I6VlsdzEjb5Qw==" media="all" rel="stylesheet">
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-f37aa76d9a859bbd1f37f62042aaae62.css" integrity="sha512-n1/Sn4ahCjLOJgIY5GxsC7k3nVQQh98dP1VWD8IY4bRInT8s8JasCOxhuTytlkZb+CotYkJ0UKp/cmTgBtGxIw==" media="all" rel="stylesheet">
# <meta content="width=device-width" name="viewport"/>
# <title>Trending  developers on GitHub today · GitHub</title>
# <meta content="GitHub is where people build software. More than 36 million people use GitHub to discover, fork, and contribute to over 100 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 36 million people use GitHub to discover, fork, and contribute to over 100 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 36 million people use GitHub to discover, fork, and contribute to over 100 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="1000" name="pjax-timeout"/>
# <meta content="D22B:2DC90:14F45BB:1FB629C:5D01478A" data-pjax-transient="" name="request-id"/>
# <meta data-pjax-transient="" name="selected-link" value="trending_developers"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="collector.githubapp.com" name="octolytics-host"><meta content="github" name="octolytics-app-id"><meta content="https://collector.githubapp.com/github-external/browser_event" name="octolytics-event-url"><meta content="D22B:2DC90:14F45BB:1FB629C:5D01478A" name="octolytics-dimension-request_id"><meta content="ams" name="octolytics-dimension-region_edge"><meta content="iad" name="octolytics-dimension-region_render">
# <meta content="UA-3769691-2" name="google-analytics"/>
# <meta class="js-ga-set" content="Logged Out" name="dimension1"/>
# <meta content="github.com" name="hostname"/>
# <meta content="" name="user-login"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="" name="js-proxy-site-detection-payload"/>
# <meta content="UNIVERSE_BANNER,MARKETPLACE_INVOICED_BILLING,MARKETPLACE_SOCIAL_PROOF_CUSTOMERS,MARKETPLACE_TRENDING_SOCIAL_PROOF,MARKETPLACE_RECOMMENDATIONS" name="enabled-features"/>
# <meta content="551ebdc9971153a9088f36c463fd7dd802e896a7" name="html-safe-nonce"/>
# <meta content="0a0d77ce326d35d4a8dc570314719d03" http-equiv="x-pjax-version"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-294181adec18ed639e160b96b45d17ac.css" integrity="sha512-MRlTIqIyb8caK5+o8llXVntXovciHyAM4qE3kWU2S7SIjAPDxYp4mE0jQp4kP5UYegy+lG9y1I6VlsdzEjb5Qw==" media="all" rel="stylesheet">
# <link data-pjax-transient="" href="https://github.com/trending/developers" rel="canonical"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta content="#1e2327" name="theme-color"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </link></meta></meta></meta></meta></meta></meta></link></link></link></head>
# <body class="logged-out env-production page-responsive">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 bg-blue text-white show-on-focus js-skip-to-content" href="#start-of-content" tabindex="1">Skip to content</a>
# <div class="pjax-loader-bar" id="js-pjax-loader-bar"><div class="progress"></div></div>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-lg d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github text-white" height="32" version="1.1" viewbox="0 0 16 16" width="32"><path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0 0 16 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path></svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 text-white no-underline border border-gray-dark rounded-2 px-2 py-1 mr-3 mr-sm-5" data-ga-click="(Logged out) Header, clicked Sign up, text:sign-up" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","client_id":null,"originating_request_id":"D22B:2DC90:14F45BB:1FB629C:5D01478A","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="17671f7b657744021e7fb4b46be28a14a03150d8343eb9f2b63f8ec9116080bb" href="/join?source=header">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="btn-link d-lg-none mt-1 js-details-target" type="button">
# <svg aria-hidden="true" class="octicon octicon-three-bars text-white" height="24" version="1.1" viewbox="0 0 12 16" width="18"><path d="M11.41 9H.59C0 9 0 8.59 0 8c0-.59 0-1 .59-1H11.4c.59 0 .59.41.59 1 0 .59 0 1-.59 1h.01zm0-4H.59C0 5 0 4.59 0 4c0-.59 0-1 .59-1H11.4c.59 0 .59.41.59 1 0 .59 0 1-.59 1h.01zM.59 11H11.4c.59 0 .59.41.59 1 0 .59 0 1-.59 1H.59C0 13 0 12.59 0 12c0-.59 0-1 .59-1z" fill-rule="evenodd"></path></svg>
# </button>
# </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom bg-gray-light p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="btn-link js-details-target" type="button">
# <svg aria-hidden="true" class="octicon octicon-x text-gray" height="24" version="1.1" viewbox="0 0 12 16" width="18"><path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd"></path></svg>
# </button>
# </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#                     Why GitHub?
#                     <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
# <path d="M1,1l6.2,6L13,1"></path>
# </svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <a class="py-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Features" href="/features">Features <span class="Bump-link-symbol float-right text-normal text-gray-light">→</span></a>
# <ul class="list-style-none f5 pb-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Code review" href="/features/code-review/">Code review</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Project management" href="/features/project-management/">Project management</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Integrations" href="/features/integrations">Integrations</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Actions" href="/features/actions">Actions</a>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Package Registry" href="/features/package-registry">Package registry</a>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Team management" href="/features#team-management">Team management</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Social coding" href="/features#social-coding">Social coding</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Documentation" href="/features#documentation">Documentation</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Code hosting" href="/features#code-hosting">Code hosting</a></li>
# </li></li></ul>
# <ul class="list-style-none mb-0 border-lg-top pt-lg-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Customer stories" href="/customer-stories">Customer stories <span class="Bump-link-symbol float-right text-normal text-gray-light">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Security" href="/security">Security <span class="Bump-link-symbol float-right text-normal text-gray-light">→</span></a></li>
# </ul>
# </div>
# </details>
# </li>
# <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, go to Enterprise" href="/enterprise">Enterprise</a>
# </li>
# <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#                     Explore
#                     <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
# <path d="M1,1l6.2,6L13,1"></path>
# </svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 pt-2 pb-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none mb-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Explore" href="/explore">Explore GitHub <span class="Bump-link-symbol float-right text-normal text-gray-light">→</span></a></li>
# </ul>
# <h4 class="text-gray-light text-normal text-mono f5 mb-2 border-lg-top pt-lg-3">Learn &amp; contribute</h4>
# <ul class="list-style-none mb-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Topics" href="/topics">Topics</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Collections" href="/collections">Collections</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Trending" href="/trending">Trending</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Learning lab" href="https://lab.github.com/">Learning Lab</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Open source guides" href="https://opensource.guide">Open source guides</a></li>
# </ul>
# <h4 class="text-gray-light text-normal text-mono f5 mb-2 border-lg-top pt-lg-3">Connect with others</h4>
# <ul class="list-style-none mb-0">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Events" href="https://github.com/events">Events</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Community forum" href="https://github.community">Community forum</a></li>
# <li class="edge-item-fix"><a class="py-2 pb-0 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to GitHub Education" href="https://education.github.com">GitHub Education</a></li>
# </ul>
# </div>
# </details>
# </li>
# <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, go to Marketplace" href="/marketplace">Marketplace</a>
# </li>
# <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#                     Pricing
#                     <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
# <path d="M1,1l6.2,6L13,1"></path>
# </svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 pt-2 pb-4 mt-0 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <a class="pb-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Pricing" href="/pricing">Plans <span class="Bump-link-symbol float-right text-normal text-gray-light">→</span></a>
# <ul class="list-style-none mb-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Compare plans" href="/pricing#feature-comparison">Compare plans</a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Contact Sales" href="https://enterprise.github.com/contact">Contact Sales</a></li>
# </ul>
# <ul class="list-style-none mb-0 border-lg-top pt-lg-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Nonprofits" href="/nonprofit">Nonprofit <span class="Bump-link-symbol float-right text-normal text-gray-light">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 pb-0 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Education" href="https://education.github.com">Education <span class="Bump-link-symbol float-right text-normal text-gray-light">→</span></a></li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex mb-3 mb-lg-0">
# <div aria-expanded="false" aria-haspopup="listbox" aria-label="Search or jump to" aria-owns="jump-to-results" class="header-search flex-self-stretch flex-lg-self-auto mr-0 mr-lg-3 mb-3 mb-lg-0 js-site-search position-relative js-jump-to" role="combobox">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --></div></div></div></div></div></div></header></div></body></html><form accept-charset="UTF-8" action="/search" aria-label="Site" class="js-site-search-form" data-unscoped-search-url="/search" method="get" role="search"><input name="utf8" type="hidden" value="✓"/>
# <label class="form-control input-sm header-search-wrapper p-0 header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center js-chromeless-input-container">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-label="Search GitHub" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations#csrf-token=YNlHFSpsCGBvqoX2/RJii8BJQd+MuNVbpZcwBqD9PX1AsSmmwONMFcoCrOq3ICToWWUI6Nvm9MGB1U9NFnzAqg==" data-scoped-placeholder="Search" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search GitHub" spellcheck="false" type="text" value=""/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <img alt="" class="mr-2 header-search-key-slash" src="https://github.githubassets.com/images/search-key-slash.svg"/>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16"><path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0 0 13 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 0 0 0-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="text-gray">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16"><path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0 0 13 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 0 0 0-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16"><path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0 0 13 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 0 0 0-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </label>
# </form>
#
#
# <a class="HeaderMenu-link no-underline mr-3" data-ga-click="(Logged out) Header, clicked Sign in, text:sign-in" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","client_id":null,"originating_request_id":"D22B:2DC90:14F45BB:1FB629C:5D01478A","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="9f5a0422aae46b73a71b248cdfa36384efbcf8c5ccfbb5ae0663de9f47025b66" href="/login?return_to=%2Ftrending%2Fdevelopers">
#           Sign in
#         </a>
# <a class="HeaderMenu-link d-inline-block no-underline border border-gray-dark rounded-1 px-2 py-1" data-ga-click="(Logged out) Header, clicked Sign up, text:sign-up" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","client_id":null,"originating_request_id":"D22B:2DC90:14F45BB:1FB629C:5D01478A","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="9f5a0422aae46b73a71b248cdfa36384efbcf8c5ccfbb5ae0663de9f47025b66" href="/join?source=header">
#             Sign up
#           </a>
#
#
#
#
#
# <div class="show-on-focus" id="start-of-content"></div>
# <div id="js-flash-container">
# </div>
# <div class="application-main" data-commit-hovercards-enabled="">
# <main>
# <div data-pjax-container="" id="container">
# <div class="bg-gray-light border-bottom">
# <div class="container-lg p-responsive text-center py-6">
# <h1 class="f0-light">Trending</h1>
# <p class="f4 text-gray col-md-8 mx-auto">
#         These are the
#         organizations and developers
#         building the hot tools today.
#       </p>
# </div>
# </div>
# <div class="explore-pjax-container container-lg p-responsive">
# <div class="d-md-flex gutter-md pt-6">
# <div class="col-md-9">
# <div class="Box">
# <div class="Box-header d-sm-flex flex-items-center flex-justify-between">
# <nav aria-label="Trending" class="subnav mb-0" data-pjax="">
# <a class="js-selected-navigation-item subnav-item" data-selected-links="trending_repositories /trending" href="/trending">Repositories</a>
# <a aria-current="page" class="js-selected-navigation-item selected subnav-item" data-selected-links="trending_developers /trending/developers" href="/trending/developers">Developers</a>
# </nav>
# <div class="mt-3 mt-sm-0 ml-sm-3">
# <details class="details-reset details-overlay select-menu select-menu-modal-right">
# <summary class="btn select-menu-button">
# <i>Date range:</i>
# <span data-menu-button="">today</span>
# </summary>
# <details-menu class="select-menu-modal position-absolute right-0" style="z-index: 99;">
# <div class="select-menu-header">
# <span class="select-menu-title">Adjust time span</span>
# </div>
# <div class="select-menu-list">
# <a aria-checked="true" class="select-menu-item" data-pjax="" href="/trending/developers?since=daily" role="menuitemradio">
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text" data-menu-button-text="">today</span>
# </a>
# <a aria-checked="false" class="select-menu-item" data-pjax="" href="/trending/developers?since=weekly" role="menuitemradio">
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text" data-menu-button-text="">this week</span>
# </a>
# <a aria-checked="false" class="select-menu-item" data-pjax="" href="/trending/developers?since=monthly" role="menuitemradio">
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text" data-menu-button-text="">this month</span>
# </a>
# </div>
# </details-menu>
# </details>
# </div>
# </div>
# <div>
# <article class="Box-row d-flex" id="pa-TrillCyborg">
# <a class="text-center text-small text-gray" href="#pa-TrillCyborg" style="width: 16px;">
#                     1
#                   </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=2574923" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/TrillCyborg"><img alt="@TrillCyborg" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/2574923?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="flex-auto">
# <h1 class="h3 lh-condensed"><a href="/TrillCyborg">Jason Werner</a></h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/TrillCyborg">TrillCyborg</a>
# </p>
# <div class="mt-1 mb-2 mb-sm-0">
# <h2 class="f5 text-normal lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/TrillCyborg/fullstack" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#     fullstack
#   </a>
# </h2>
# <div class="f6 text-gray mt-1">
#     React/ApolloGraphQL/Node/Mongo demo written in Typescript
#   </div>
# </div>
# </div>
# <div class="d-flex ml-sm-3">
# <div class="mr-2">
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"D22B:2DC90:14F45BB:1FB629C:5D01478A","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="ca7edb57a8b4a5ca394f67a2ba12a576dde1411c85304cafb4b8399051ee3cc9" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>
# <article class="Box-row d-flex" id="pa-0voice">
# <a class="text-center text-small text-gray" href="#pa-0voice" style="width: 16px;">
#                     2
#                   </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/0voice/hovercard" href="/0voice"><img alt="@0voice" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/43104160?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="flex-auto">
# <h1 class="h3 lh-condensed"><a href="/0voice">0voice</a></h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/0voice">0voice</a>
# </p>
# <div class="mt-1 mb-2 mb-sm-0">
# <h2 class="f5 text-normal lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/0voice/from_coder_to_expert" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#     from_coder_to_expert
#   </a>
# </h2>
# <div class="f6 text-gray mt-1">
#     2019年最新总结，从程序员到CTO，从专业走向卓越，分享大牛企业内部pdf与PPT
#   </div>
# </div>
# </div>
# <div class="d-flex ml-sm-3">
# <div class="mr-2">
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# </div>
# </div>
# </div>
# </div>
# </article>
# <article class="Box-row d-flex" id="pa-pingcap">
# <a class="text-center text-small text-gray" href="#pa-pingcap" style="width: 16px;">
#                     3
#                   </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/pingcap/hovercard" href="/pingcap"><img alt="@pingcap" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/11855343?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="flex-auto">
# <h1 class="h3 lh-condensed"><a href="/pingcap">PingCAP</a></h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/pingcap">pingcap</a>
# </p>
# <div class="mt-1 mb-2 mb-sm-0">
# <h2 class="f5 text-normal lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/pingcap/tidb" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#     tidb
#   </a>
# </h2>
# <div class="f6 text-gray mt-1">
#     TiDB is a distributed HTAP database compatible with the MySQL protocol
#   </div>
# </div>
# </div>
# <div class="d-flex ml-sm-3">
# <div class="mr-2">
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# </div>
# </div>
# </div>
# </div>
# </article>
# <article class="Box-row d-flex" id="pa-microsoft">
# <a class="text-center text-small text-gray" href="#pa-microsoft" style="width: 16px;">
#                     4
#                   </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/microsoft/hovercard" href="/microsoft"><img alt="@microsoft" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/6154722?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="flex-auto">
# <h1 class="h3 lh-condensed"><a href="/microsoft">Microsoft</a></h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/microsoft">microsoft</a>
# </p>
# <div class="mt-1 mb-2 mb-sm-0">
# <h2 class="f5 text-normal lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/microsoft/vscode" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#     vscode
#   </a>
# </h2>
# <div class="f6 text-gray mt-1">
#     Visual Studio Code
#   </div>
# </div>
# </div>
# <div class="d-flex ml-sm-3">
# <div class="mr-2">
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# </div>
# </div>
# </div>
# </div>
# </article>
# <article class="Box-row d-flex" id="pa-rasbt">
# <a class="text-center text-small text-gray" href="#pa-rasbt" style="width: 16px;">
#                     5
#                   </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=5618407" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/rasbt"><img alt="@rasbt" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/5618407?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="flex-auto">
# <h1 class="h3 lh-condensed"><a href="/rasbt">Sebastian Raschka</a></h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/rasbt">rasbt</a>
# </p>
# <div class="mt-1 mb-2 mb-sm-0">
# <h2 class="f5 text-normal lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/rasbt/python-machine-learning-book" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#     python-machine-learning-book
#   </a>
# </h2>
# <div class="f6 text-gray mt-1">
#     The "Python Machine Learning (1st edition)" book code repository and info resource
#   </div>
# </div>
# </div>
# <div class="d-flex ml-sm-3">
# <div class="mr-2">
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"D22B:2DC90:14F45BB:1FB629C:5D01478A","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="ca7edb57a8b4a5ca394f67a2ba12a576dde1411c85304cafb4b8399051ee3cc9" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>
# <article class="Box-row d-flex" id="pa-jackfrued">
# <a class="text-center text-small text-gray" href="#pa-jackfrued" style="width: 16px;">
#                     6
#                   </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=7474657" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/jackfrued"><img alt="@jackfrued" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/7474657?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="flex-auto">
# <h1 class="h3 lh-condensed"><a href="/jackfrued">骆昊</a></h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/jackfrued">jackfrued</a>
# </p>
# <div class="mt-1 mb-2 mb-sm-0">
# <h2 class="f5 text-normal lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/jackfrued/Python-100-Days" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#     Python-100-Days
#   </a>
# </h2>
# <div class="f6 text-gray mt-1">
#     Python - 100天从新手到大师
#   </div>
# </div>
# </div>
# <div class="d-flex ml-sm-3">
# <div class="mr-2">
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"D22B:2DC90:14F45BB:1FB629C:5D01478A","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="ca7edb57a8b4a5ca394f67a2ba12a576dde1411c85304cafb4b8399051ee3cc9" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>
# <article class="Box-row d-flex" id="pa-apache">
# <a class="text-center text-small text-gray" href="#pa-apache" style="width: 16px;">
#                     7
#                   </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/apache/hovercard" href="/apache"><img alt="@apache" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/47359?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="flex-auto">
# <h1 class="h3 lh-condensed"><a href="/apache">The Apache Software Foundation</a></h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/apache">apache</a>
# </p>
# <div class="mt-1 mb-2 mb-sm-0">
# <h2 class="f5 text-normal lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/apache/incubator-echarts" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#     incubator-echarts
#   </a>
# </h2>
# <div class="f6 text-gray mt-1">
#     A powerful, interactive charting and visualization library for browser
#   </div>
# </div>
# </div>
# <div class="d-flex ml-sm-3">
# <div class="mr-2">
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# </div>
# </div>
# </div>
# </div>
# </article>
# <article class="Box-row d-flex" id="pa-github">
# <a class="text-center text-small text-gray" href="#pa-github" style="width: 16px;">
#                     8
#                   </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/github/hovercard" href="/github"><img alt="@github" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/9919?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="flex-auto">
# <h1 class="h3 lh-condensed"><a href="/github">GitHub</a></h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/github">github</a>
# </p>
# <div class="mt-1 mb-2 mb-sm-0">
# <h2 class="f5 text-normal lh-condensed">
# ...
# <span data-menu-button-text="">Zephir</span>
# </a> <a class="select-menu-item" href="/trending/developers/zig?since=daily" role="menuitemradio">
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span data-menu-button-text="">Zig</span>
# </a> <a class="select-menu-item" href="/trending/developers/zil?since=daily" role="menuitemradio">
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span data-menu-button-text="">ZIL</span>
# </a> <a class="select-menu-item" href="/trending/developers/zimpl?since=daily" role="menuitemradio">
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span data-menu-button-text="">Zimpl</span>
# </a> </div>
# </div>
# <div class="select-menu-loading-overlay anim-pulse">
# <svg aria-hidden="true" class="octicon octicon-octoface" height="32" version="1.1" viewbox="0 0 16 16" width="32"><path d="M14.7 5.34c.13-.32.55-1.59-.13-3.31 0 0-1.05-.33-3.44 1.3-1-.28-2.07-.32-3.13-.32s-2.13.04-3.13.32c-2.39-1.64-3.44-1.3-3.44-1.3-.68 1.72-.26 2.99-.13 3.31C.49 6.21 0 7.33 0 8.69 0 13.84 3.33 15 7.98 15S16 13.84 16 8.69c0-1.36-.49-2.48-1.3-3.35zM8 14.02c-3.3 0-5.98-.15-5.98-3.35 0-.76.38-1.48 1.02-2.07 1.07-.98 2.9-.46 4.96-.46 2.07 0 3.88-.52 4.96.46.65.59 1.02 1.3 1.02 2.07 0 3.19-2.68 3.35-5.98 3.35zM5.49 9.01c-.66 0-1.2.8-1.2 1.78s.54 1.79 1.2 1.79c.66 0 1.2-.8 1.2-1.79s-.54-1.78-1.2-1.78zm5.02 0c-.66 0-1.2.79-1.2 1.78s.54 1.79 1.2 1.79c.66 0 1.2-.8 1.2-1.79s-.53-1.78-1.2-1.78z" fill-rule="evenodd"></path></svg>
# </div>
# </details-menu>
# </details>
# <div class="protip protip-callout">
# <strong class="protip">ProTip!</strong>
#   Looking for most forked  repositories?
#   <a href="/search?q=stars%3A%3E1&amp;s=forks&amp;type=Repositories">Try this search</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <div class="modal-backdrop js-touch-events"></div>
# </div>
# <footer class="footer mt-6">
# <div class="container-lg p-responsive">
# <div class="d-flex flex-wrap py-5 mb-5">
# <div class="col-12 col-lg-4 mb-5">
# <a aria-label="Go to GitHub homepage" class="text-gray-dark" data-ga-click="Footer, go to home, text:home" href="/">
# <svg aria-hidden="true" class="octicon octicon-logo-github" height="30" version="1.1" viewbox="0 0 45 16" width="84"><path d="M18.53 12.03h-.02c.009 0 .015.01.024.011h.006l-.01-.01zm.004.011c-.093.001-.327.05-.574.05-.78 0-1.05-.36-1.05-.83V8.13h1.59c.09 0 .16-.08.16-.19v-1.7c0-.09-.08-.17-.16-.17h-1.59V3.96c0-.08-.05-.13-.14-.13h-2.16c-.09 0-.14.05-.14.13v2.17s-1.09.27-1.16.28c-.08.02-.13.09-.13.17v1.36c0 .11.08.19.17.19h1.11v3.28c0 2.44 1.7 2.69 2.86 2.69.53 0 1.17-.17 1.27-.22.06-.02.09-.09.09-.16v-1.5a.177.177 0 0 0-.146-.18zM42.23 9.84c0-1.81-.73-2.05-1.5-1.97-.6.04-1.08.34-1.08.34v3.52s.49.34 1.22.36c1.03.03 1.36-.34 1.36-2.25zm2.43-.16c0 3.43-1.11 4.41-3.05 4.41-1.64 0-2.52-.83-2.52-.83s-.04.46-.09.52c-.03.06-.08.08-.14.08h-1.48c-.1 0-.19-.08-.19-.17l.02-11.11c0-.09.08-.17.17-.17h2.13c.09 0 .17.08.17.17v3.77s.82-.53 2.02-.53l-.01-.02c1.2 0 2.97.45 2.97 3.88zm-8.72-3.61h-2.1c-.11 0-.17.08-.17.19v5.44s-.55.39-1.3.39-.97-.34-.97-1.09V6.25c0-.09-.08-.17-.17-.17h-2.14c-.09 0-.17.08-.17.17v5.11c0 2.2 1.23 2.75 2.92 2.75 1.39 0 2.52-.77 2.52-.77s.05.39.08.45c.02.05.09.09.16.09h1.34c.11 0 .17-.08.17-.17l.02-7.47c0-.09-.08-.17-.19-.17zm-23.7-.01h-2.13c-.09 0-.17.09-.17.2v7.34c0 .2.13.27.3.27h1.92c.2 0 .25-.09.25-.27V6.23c0-.09-.08-.17-.17-.17zm-1.05-3.38c-.77 0-1.38.61-1.38 1.38 0 .77.61 1.38 1.38 1.38.75 0 1.36-.61 1.36-1.38 0-.77-.61-1.38-1.36-1.38zm16.49-.25h-2.11c-.09 0-.17.08-.17.17v4.09h-3.31V2.6c0-.09-.08-.17-.17-.17h-2.13c-.09 0-.17.08-.17.17v11.11c0 .09.09.17.17.17h2.13c.09 0 .17-.08.17-.17V8.96h3.31l-.02 4.75c0 .09.08.17.17.17h2.13c.09 0 .17-.08.17-.17V2.6c0-.09-.08-.17-.17-.17zM8.81 7.35v5.74c0 .04-.01.11-.06.13 0 0-1.25.89-3.31.89-2.49 0-5.44-.78-5.44-5.92S2.58 1.99 5.1 2c2.18 0 3.06.49 3.2.58.04.05.06.09.06.14L7.94 4.5c0 .09-.09.2-.2.17-.36-.11-.9-.33-2.17-.33-1.47 0-3.05.42-3.05 3.73s1.5 3.7 2.58 3.7c.92 0 1.25-.11 1.25-.11v-2.3H4.88c-.11 0-.19-.08-.19-.17V7.35c0-.09.08-.17.19-.17h3.74c.11 0 .19.08.19.17z" fill-rule="evenodd"></path></svg>
# </a>
# </div>
# <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-lg-0 pl-lg-4">
# <h2 class="h5 mb-3 text-mono text-gray-light text-normal">Product</h2>
# <ul class="list-style-none text-gray f5">
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to features, text:features" href="/features">Features</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to security, text:security" href="/security">Security</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to enterprise, text:enterprise" href="/enterprise">Enterprise</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to customer stories, text:customer stories" href="/customer-stories">Customer stories</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to pricing, text:pricing" href="/pricing">Pricing</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to resources, text:resources" href="https://resources.github.com">Resources</a></li>
# </ul>
# </div>
# <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-md-0 pl-md-4">
# <h2 class="h5 mb-3 text-mono text-gray-light text-normal">Platform</h2>
# <ul class="list-style-none f5">
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to api, text:api" href="https://developer.github.com">Developer API</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to partner, text:partner" href="http://partner.github.com/">Partners</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to atom, text:atom" href="https://atom.io">Atom</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to electron, text:electron" href="http://electron.atom.io/">Electron</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to desktop, text:desktop" href="https://desktop.github.com/">GitHub Desktop</a></li>
# </ul>
# </div>
# <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-md-0 pl-md-4">
# <h2 class="h5 mb-3 text-mono text-gray-light text-normal">Support</h2>
# <ul class="list-style-none f5">
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to help, text:help" href="https://help.github.com">Help</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to community, text:community" href="https://github.community">Community Forum</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to training, text:training" href="https://services.github.com/">Training</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to status, text:status" href="https://githubstatus.com/">Status</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to contact, text:contact" href="https://github.com/contact">Contact GitHub</a></li>
# </ul>
# </div>
# <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-md-0 pl-md-4">
# <h2 class="h5 mb-3 text-mono text-gray-light text-normal">Company</h2>
# <ul class="list-style-none f5">
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to blog, text:blog" href="https://github.blog">Blog</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to careers, text:careers" href="/about/careers">Careers</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to press, text:press" href="/about/press">Press</a></li>
# <li class="lh-condensed mb-3"><a class="link-gray" data-ga-click="Footer, go to shop, text:shop" href="https://shop.github.com">Shop</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="bg-gray-light">
# <div class="container-lg p-responsive f6 py-4 d-sm-flex flex-justify-between flex-row-reverse flex-items-center">
# <ul class="list-style-none d-flex flex-items-center mb-3 mb-sm-0 lh-condensed-ultra">
# <li class="mr-3"><a data-ga-click="Footer, go to Twitter, text:twitter" href="https://twitter.com/github" style="color: #959da5;" title="GitHub on Twitter"><svg class="d-block" height="18" viewbox="0 0 273.5 222.3" xmlns="http://www.w3.org/2000/svg"><path d="M273.5 26.3a109.77 109.77 0 0 1-32.2 8.8 56.07 56.07 0 0 0 24.7-31 113.39 113.39 0 0 1-35.7 13.6 56.1 56.1 0 0 0-97 38.4 54 54 0 0 0 1.5 12.8A159.68 159.68 0 0 1 19.1 10.3a56.12 56.12 0 0 0 17.4 74.9 56.06 56.06 0 0 1-25.4-7v.7a56.11 56.11 0 0 0 45 55 55.65 55.65 0 0 1-14.8 2 62.39 62.39 0 0 1-10.6-1 56.24 56.24 0 0 0 52.4 39 112.87 112.87 0 0 1-69.7 24 119 119 0 0 1-13.4-.8 158.83 158.83 0 0 0 86 25.2c103.2 0 159.6-85.5 159.6-159.6 0-2.4-.1-4.9-.2-7.3a114.25 114.25 0 0 0 28.1-29.1" fill="currentColor"></path></svg>
# </a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to Facebook, text:facebook" href="https://www.facebook.com/GitHub" style="color: #959da5;" title="GitHub on Facebook"><svg class="d-block" height="18" viewbox="0 0 15.3 15.4" xmlns="http://www.w3.org/2000/svg"><path d="M14.5 0H.8a.88.88 0 0 0-.8.9v13.6a.88.88 0 0 0 .8.9h7.3v-6h-2V7.1h2V5.4a2.87 2.87 0 0 1 2.5-3.1h.5a10.87 10.87 0 0 1 1.8.1v2.1h-1.3c-1 0-1.1.5-1.1 1.1v1.5h2.3l-.3 2.3h-2v5.9h3.9a.88.88 0 0 0 .9-.8V.8a.86.86 0 0 0-.8-.8z" fill="currentColor"></path></svg>
# </a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to YouTube, text:youtube" href="https://www.youtube.com/github" style="color: #959da5;" title="GitHub on YouTube"><svg class="d-block" height="16" viewbox="0 0 19.17 13.6" xmlns="http://www.w3.org/2000/svg"><path d="M18.77 2.13A2.4 2.4 0 0 0 17.09.42C15.59 0 9.58 0 9.58 0a57.55 57.55 0 0 0-7.5.4A2.49 2.49 0 0 0 .39 2.13 26.27 26.27 0 0 0 0 6.8a26.15 26.15 0 0 0 .39 4.67 2.43 2.43 0 0 0 1.69 1.71c1.52.42 7.5.42 7.5.42a57.69 57.69 0 0 0 7.51-.4 2.4 2.4 0 0 0 1.68-1.71 25.63 25.63 0 0 0 .4-4.67 24 24 0 0 0-.4-4.69zM7.67 9.71V3.89l5 2.91z" fill="currentColor"></path></svg>
# </a></li>
# <li class="mr-3 flex-self-start"><a data-ga-click="Footer, go to Linkedin, text:linkedin" href="https://www.linkedin.com/company/github" style="color: #959da5;" title="GitHub on Linkedin"><svg class="d-block" height="18" viewbox="0 0 19 18" xmlns="http://www.w3.org/2000/svg"><path d="M3.94 2A2 2 0 1 1 2 0a2 2 0 0 1 1.94 2zM4 5.48H0V18h4zm6.32 0H6.34V18h3.94v-6.57c0-3.66 4.77-4 4.77 0V18H19v-7.93c0-6.17-7.06-5.94-8.72-2.91z" fill="currentColor"></path></svg>
# </a></li>
# <li><a data-ga-click="Footer, go to github's org, text:github" href="https://github.com/github" style="color: #959da5;" title="GitHub's organization"><svg alt="GitHub" aria-hidden="true" class="octicon octicon-mark-github d-block" height="20" version="1.1" viewbox="0 0 16 16" width="20"><path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0 0 16 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path></svg></a></li>
# </ul>
# <ul class="list-style-none d-flex text-gray">
# <li class="mr-3">© 2019 GitHub, Inc.</li>
# <li class="mr-3"><a class="link-gray" data-ga-click="Footer, go to terms, text:terms" href="/site/terms">Terms</a></li>
# <li><a class="link-gray" data-ga-click="Footer, go to privacy, text:privacy" href="/site/privacy">Privacy</a></li>
# </ul>
# </div>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 0 0 0 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 0 0 .01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd"></path></svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd"></path></svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <script crossorigin="anonymous" integrity="sha512-BlCvumXWTvpASEdhCGiahDUDf7Bwb8QXA2XnnSnqJ9QafxcNcrNYUNYS2wXmd3nEpO//+zlZa9DSV9zmu5MqRg==" src="https://github.githubassets.com/assets/compat-bootstrap-90c0ace0.js" type="application/javascript"></script>
# <script crossorigin="anonymous" integrity="sha512-yXTQYjjrB+NYuR3xxMLmgJa+xp2KGNz9TD98a9SSMeMQ3d6/FhYFRrLLAIuuq9W6yFSPxli903O7vG6hwKXwvw==" src="https://github.githubassets.com/assets/frameworks-2d8937db.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-fQBbrL73NxkEtbeIwu3JQjAAqxFUNclJ0bgKLftq3Q8pfQqbJ7maiHP+a+4VSz/eu6ro3/QlwON2Rtxi+sDCVw==" src="https://github.githubassets.com/assets/github-bootstrap-916a1ab8.js" type="application/javascript"></script>
# <div class="js-stale-session-flash stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 0 0 0 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 0 0 .01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd"></path></svg>
# <span class="signed-in-tab-flash">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="signed-out-tab-flash">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default text-gray-dark hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd"></path></svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box box-shadow-large" style="width:360px;">
# </div>
# </div>
# <div aria-live="polite" class="js-global-screen-reader-notice sr-only"></div>

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code

#with open ("github_trending", "w") as github_trending_file:
    #github_trending_file.write(response.text)

#lines = lines_container.find_all("a",{"role":"link"})

container = soup.find_all("h2",'f3 text-normal')
print(container)

developers_list = []
for developer in container:
    nick_name = developer.find('a')
    print(nick_name)
    nombre = nick_name.text.strip().replace('\n', ' ')
    nombre = re.sub('\s{2,}',',',nombre)
    developers_list.append(nombre)
print(developers_list)
# Out:
# []
# []

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

url = 'https://github.com/trending/python?since=daily'

with open ("github_trending_2", "w") as github_trending_2_file:
    github_trending_2_file.write(response.text)
    
repos_container = soup.find_all("h3")

repos_list = []
for repos in repos_container:
    repos = repos.find("a")
    repos = repos.text.replace('\n', '')
    repos_list.append(repos)
    
repos_list
# Out:
# []

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
rq = requests.get(url)
sp = BeautifulSoup(rq.text,"html.parser")

with open("Walt Disney", "w") as WD_file:
    WD_file.write(rq.text)
    
images = sp.find_all('a','image')

image_list= []
for image in images:
    image = image.get('href')
    image_list.append(image)
image_list
# Out:
# ['/wiki/File:Walt_Disney_1946.JPG',
#  '/wiki/File:Walt_Disney_1942_signature.svg',
#  '/wiki/File:Walt_Disney_envelope_ca._1921.jpg',
#  '/wiki/File:Trolley_Troubles_poster.jpg',
#  '/wiki/File:Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  '/wiki/File:Steamboat-willie.jpg',
#  '/wiki/File:Walt_Disney_1935.jpg',
#  '/wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg',
#  '/wiki/File:Disney_drawing_goofy.jpg',
#  '/wiki/File:DisneySchiphol1951.jpg',
#  '/wiki/File:WaltDisneyplansDisneylandDec1954.jpg',
#  '/wiki/File:Walt_disney_portrait_right.jpg',
#  '/wiki/File:Walt_Disney_Grave.JPG',
#  '/wiki/File:Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  '/wiki/File:Disney_Display_Case.JPG',
#  '/wiki/File:Disney1968.jpg',
#  '/wiki/File:Animation_disc.svg',
#  '/wiki/File:P_vip.svg',
#  '/wiki/File:Magic_Kingdom_castle.jpg',
#  '/wiki/File:Video-x-generic.svg',
#  '/wiki/File:Flag_of_Los_Angeles_County,_California.svg',
#  '/wiki/File:USA_flag_on_television.svg']

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
rq = requests.get(url)
sp = BeautifulSoup(rq.text, 'html.parser')
with open ("wikiwiki", "w") as wiki_file:
    wiki_file.write(rq.text)

links = link_container.find_all('a')

links_list = []
for link in links:
    link = url + link.get('href')
    links_list.append(link)
links_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-103367ea06f0> in <module>
#       5     wiki_file.write(rq.text)
#       6
# ----> 7 links = link_container.find_all('a')
#       8
#       9 links_list = []
#
# NameError: name 'link_container' is not defined

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
rq = requests.get(url)
soup = BeautifulSoup(rq.text)

chanched_titles = soup.find_all('div','usctitlechanged')
chanched_titles
# Out:
# [<div class="usctitlechanged" id="us/usc/t7">
#
#            Title 7 - Agriculture
#
#          </div>, <div class="usctitlechanged" id="us/usc/t42">
#
#            Title 42 - The Public Health and Welfare
#
#          </div>]

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
response = requests.get(url)
soap = BeautifulSoup(response.text)

with open ("TMW", "w") as TMW:
    TMW.write(response.text)

images = soup.find_all('img', '')

most_wanted_list = []
for name in images:
    name = name.get('alt')
    most_wanted_list.append(name)
most_wanted_list
# Out:
# ['OLRC home',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code
rq = requests.get(url)
soap = BeautifulSoup(rq.text)
rows = soap.find_all('tr', 'ligne1 normal')

# %%
lista_values = []
for value in rows:
    value.get("td")
    lista_values.append(value.text)
lista_values
# Out:
# ['earthquake2019-06-12\xa0\xa0\xa018:16:20.621min ago37.55\xa0N\xa0\xa0117.92\xa0W\xa0\xa07ml3.6\xa0NEVADA2019-06-12 18:20',
#  'earthquake2019-06-12\xa0\xa0\xa017:17:23.01hr 20min ago30.38\xa0S\xa0\xa0117.75\xa0E\xa0\xa02M 2.3\xa0WESTERN AUSTRALIA2019-06-12 17:55',
#  'earthquake2019-06-12\xa0\xa0\xa017:07:55.91hr 30min ago36.86\xa0N\xa0\xa03.61\xa0E\xa0\xa021mb3.5\xa0NORTHERN ALGERIA2019-06-12 17:19',
#  'earthquake2019-06-12\xa0\xa0\xa016:44:39.01hr 53min ago8.75\xa0S\xa0\xa0123.93\xa0E\xa0\xa010 M4.8\xa0FLORES REGION, INDONESIA2019-06-12 16:55',
#  'earthquake2019-06-12\xa0\xa0\xa016:33:00.02hr 05min ago21.73\xa0S\xa0\xa068.78\xa0W\xa0\xa0104ML3.2\xa0ANTOFAGASTA, CHILE2019-06-12 16:54',
#  'Fearthquake2019-06-12\xa0\xa0\xa016:22:58.82hr 15min ago40.49\xa0N\xa0\xa020.82\xa0E\xa0\xa01ML2.5\xa0ALBANIA2019-06-12 16:35',
#  'earthquake2019-06-12\xa0\xa0\xa015:50:37.82hr 47min ago38.80\xa0N\xa0\xa015.75\xa0E\xa0\xa0170ML2.4\xa0SICILY, ITALY2019-06-12 16:36',
#  'earthquake2019-06-12\xa0\xa0\xa015:28:01.93hr 10min ago37.28\xa0N\xa0\xa0115.22\xa0W\xa0\xa08ml2.0\xa0NEVADA2019-06-12 16:58',
#  'earthquake2019-06-12\xa0\xa0\xa015:09:24.03hr 28min ago30.34\xa0S\xa0\xa0117.71\xa0E\xa0\xa02M 2.1\xa0WESTERN AUSTRALIA2019-06-12 17:50',
#  'earthquake2019-06-12\xa0\xa0\xa013:51:30.04hr 46min ago9.75\xa0N\xa0\xa084.39\xa0W\xa0\xa046 M3.3\xa0COSTA RICA2019-06-12 14:15',
#  'earthquake2019-06-12\xa0\xa0\xa011:43:35.46hr 54min ago40.11\xa0N\xa0\xa0122.16\xa0W\xa0\xa029Md2.6\xa0NORTHERN CALIFORNIA2019-06-12 18:17',
#  'earthquake2019-06-12\xa0\xa0\xa010:35:07.58hr 02min ago38.24\xa0N\xa0\xa0141.72\xa0E\xa0\xa045mb4.7\xa0NEAR EAST COAST OF HONSHU, JAPAN2019-06-12 14:55',
#  'earthquake2019-06-12\xa0\xa0\xa009:59:13.08hr 38min ago18.14\xa0N\xa0\xa0103.46\xa0W\xa0\xa04 M3.7\xa0OFFSHORE MICHOACAN, MEXICO2019-06-12 13:02',
#  'earthquake2019-06-12\xa0\xa0\xa009:32:39.09hr 05min ago2.62\xa0S\xa0\xa079.66\xa0W\xa0\xa021 M3.7\xa0NEAR COAST OF ECUADOR2019-06-12 09:35',
#  'earthquake2019-06-12\xa0\xa0\xa009:13:19.49hr 24min ago3.43\xa0S\xa0\xa0102.75\xa0W\xa0\xa010mb4.4\xa0CENTRAL EAST PACIFIC RISE2019-06-12 14:55',
#  'earthquake2019-06-12\xa0\xa0\xa008:49:53.59hr 48min ago19.03\xa0N\xa0\xa068.35\xa0W\xa0\xa0110Md3.0\xa0DOMINICAN REPUBLIC REGION2019-06-12 11:56',
#  "earthquake2019-06-12\xa0\xa0\xa008:45:32.59hr 52min ago41.77\xa0N\xa0\xa043.12\xa0E\xa0\xa01ML3.3\xa0GEORGIA (SAK'ART'VELO)2019-06-12 09:35",
#  'earthquake2019-06-12\xa0\xa0\xa008:18:24.710hr 19min ago41.63\xa0N\xa0\xa012.81\xa0E\xa0\xa09ML2.0\xa0SOUTHERN ITALY2019-06-12 08:27',
#  'earthquake2019-06-12\xa0\xa0\xa008:17:30.010hr 20min ago16.60\xa0N\xa0\xa098.56\xa0W\xa0\xa011 M3.5\xa0GUERRERO, MEXICO2019-06-12 13:02',
#  'earthquake2019-06-12\xa0\xa0\xa008:08:34.110hr 29min ago20.01\xa0N\xa0\xa0155.94\xa0W\xa0\xa011Md2.2\xa0HAWAII REGION, HAWAII2019-06-12 08:11',
#  'earthquake2019-06-12\xa0\xa0\xa008:02:27.010hr 35min ago31.13\xa0S\xa0\xa071.72\xa0W\xa0\xa034ML3.6\xa0OFFSHORE COQUIMBO, CHILE2019-06-12 08:18',
#  'earthquake2019-06-12\xa0\xa0\xa007:36:18.011hr 01min ago37.40\xa0S\xa0\xa074.11\xa0W\xa0\xa019ML3.9\xa0OFFSHORE BIO-BIO, CHILE2019-06-12 07:47',
#  'earthquake2019-06-12\xa0\xa0\xa007:24:24.011hr 13min ago19.48\xa0N\xa0\xa069.81\xa0W\xa0\xa016 M3.2\xa0DOMINICAN REPUBLIC REGION2019-06-12 17:55',
#  'earthquake2019-06-12\xa0\xa0\xa007:06:46.011hr 31min ago16.26\xa0N\xa0\xa098.01\xa0W\xa0\xa06 M3.3\xa0OAXACA, MEXICO2019-06-12 13:03',
#  'Fearthquake2019-06-12\xa0\xa0\xa006:46:57.011hr 51min ago8.14\xa0S\xa0\xa0117.71\xa0E\xa0\xa010 M4.4\xa0SUMBAWA REGION, INDONESIA2019-06-12 07:00']

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code

# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

ea_html = requests.get(url).text
soup_ea = BeautifulSoup(ea_html, "html.parser")

# %%
data = []
table = soup_ea.find_all('tr', class_= 'ligne1 normal')
table
# Out:
# [<tr class="ligne1 normal" id="770935" onclick="go_details(event,770935);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770935">2019-06-12   18:42:41.9</a></b><i class="ago" id="ago0">16min ago</i></td><td class="tabev1">38.81 </td><td class="tabev2">N  </td><td class="tabev1">26.48 </td><td class="tabev2">E  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp0">ML</td><td class="tabev2">2.7</td><td class="tb_region" id="reg0"> NEAR THE COAST OF WESTERN TURKEY</td><td class="comment updatetimeno" id="upd0" style="text-align:right;">2019-06-12 18:57</td></tr>,
#  <tr class="ligne1 normal" id="770936" onclick="go_details(event,770936);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=770936&amp;f=/INTENSITY_MAPS/77/770936/AUTOMATIC/AreaThreshold_5/EMS_98__RMW_Musson/LocMethod_PerClusterCity/DynamicClusters_MaxSize50/IntensityMapThumbnails.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#FFFFFF;">F</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770936">2019-06-12   18:02:58.3</a></b><i class="ago" id="ago2">55min ago</i></td><td class="tabev1">34.43 </td><td class="tabev2">N  </td><td class="tabev1">45.62 </td><td class="tabev2">E  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp2">ML</td><td class="tabev2">3.5</td><td class="tb_region" id="reg2"> IRAN-IRAQ BORDER REGION</td><td class="comment updatetimeno" id="upd2" style="text-align:right;">2019-06-12 18:54</td></tr>,
#  <tr class="ligne1 normal" id="770932" onclick="go_details(event,770932);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770932">2019-06-12   17:17:23.0</a></b><i class="ago" id="ago4">1hr 41min ago</i></td><td class="tabev1">30.38 </td><td class="tabev2">S  </td><td class="tabev1">117.75 </td><td class="tabev2">E  </td><td class="tabev3">2</td><td class="tabev5" id="magtyp4">M </td><td class="tabev2">2.3</td><td class="tb_region" id="reg4"> WESTERN AUSTRALIA</td><td class="comment updatetimeno" id="upd4" style="text-align:right;">2019-06-12 17:55</td></tr>,
#  <tr class="ligne1 normal" id="770928" onclick="go_details(event,770928);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770928">2019-06-12   17:07:55.9</a></b><i class="ago" id="ago6">1hr 50min ago</i></td><td class="tabev1">36.86 </td><td class="tabev2">N  </td><td class="tabev1">3.61 </td><td class="tabev2">E  </td><td class="tabev3">21</td><td class="tabev5" id="magtyp6">mb</td><td class="tabev2">3.5</td><td class="tb_region" id="reg6"> NORTHERN ALGERIA</td><td class="comment updatetimeno" id="upd6" style="text-align:right;">2019-06-12 17:19</td></tr>,
#  <tr class="ligne1 normal" id="770922" onclick="go_details(event,770922);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770922">2019-06-12   16:44:39.0</a></b><i class="ago" id="ago8">2hr 14min ago</i></td><td class="tabev1">8.75 </td><td class="tabev2">S  </td><td class="tabev1">123.93 </td><td class="tabev2">E  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp8"> M</td><td class="tabev2">4.8</td><td class="tb_region" id="reg8"> FLORES REGION, INDONESIA</td><td class="comment updatetimeno" id="upd8" style="text-align:right;">2019-06-12 16:55</td></tr>,
#  <tr class="ligne1 normal" id="770921" onclick="go_details(event,770921);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770921">2019-06-12   16:33:00.0</a></b><i class="ago" id="ago10">2hr 25min ago</i></td><td class="tabev1">21.73 </td><td class="tabev2">S  </td><td class="tabev1">68.78 </td><td class="tabev2">W  </td><td class="tabev3">104</td><td class="tabev5" id="magtyp10">ML</td><td class="tabev2">3.2</td><td class="tb_region" id="reg10"> ANTOFAGASTA, CHILE</td><td class="comment updatetimeno" id="upd10" style="text-align:right;">2019-06-12 16:54</td></tr>,
#  <tr class="ligne1 normal" id="770918" onclick="go_details(event,770918);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=770918&amp;f=/INTENSITY_MAPS/77/770918/AUTOMATIC/AreaThreshold_5/EMS_98__RMW_Musson/LocMethod_PerClusterCity/DynamicClusters_MaxSize50/IntensityMapThumbnails.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#FFFFFF;">F</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770918">2019-06-12   16:22:58.8</a></b><i class="ago" id="ago12">2hr 35min ago</i></td><td class="tabev1">40.49 </td><td class="tabev2">N  </td><td class="tabev1">20.82 </td><td class="tabev2">E  </td><td class="tabev3">1</td><td class="tabev5" id="magtyp12">ML</td><td class="tabev2">2.5</td><td class="tb_region" id="reg12"> ALBANIA</td><td class="comment updatetimeno" id="upd12" style="text-align:right;">2019-06-12 16:35</td></tr>,
#  <tr class="ligne1 normal" id="770913" onclick="go_details(event,770913);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770913">2019-06-12   15:50:37.8</a></b><i class="ago" id="ago14">3hr 08min ago</i></td><td class="tabev1">38.80 </td><td class="tabev2">N  </td><td class="tabev1">15.75 </td><td class="tabev2">E  </td><td class="tabev3">170</td><td class="tabev5" id="magtyp14">ML</td><td class="tabev2">2.4</td><td class="tb_region" id="reg14"> SICILY, ITALY</td><td class="comment updatetimeno" id="upd14" style="text-align:right;">2019-06-12 16:36</td></tr>,
#  <tr class="ligne1 normal" id="770925" onclick="go_details(event,770925);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770925">2019-06-12   15:28:01.9</a></b><i class="ago" id="ago16">3hr 30min ago</i></td><td class="tabev1">37.28 </td><td class="tabev2">N  </td><td class="tabev1">115.22 </td><td class="tabev2">W  </td><td class="tabev3">8</td><td class="tabev5" id="magtyp16">ml</td><td class="tabev2">2.0</td><td class="tb_region" id="reg16"> NEVADA</td><td class="comment updatetimeno" id="upd16" style="text-align:right;">2019-06-12 16:58</td></tr>,
#  <tr class="ligne1 normal" id="770931" onclick="go_details(event,770931);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770931">2019-06-12   15:09:24.0</a></b><i class="ago" id="ago18">3hr 49min ago</i></td><td class="tabev1">30.34 </td><td class="tabev2">S  </td><td class="tabev1">117.71 </td><td class="tabev2">E  </td><td class="tabev3">2</td><td class="tabev5" id="magtyp18">M </td><td class="tabev2">2.1</td><td class="tb_region" id="reg18"> WESTERN AUSTRALIA</td><td class="comment updatetimeno" id="upd18" style="text-align:right;">2019-06-12 17:50</td></tr>,
#  <tr class="ligne1 normal" id="770908" onclick="go_details(event,770908);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770908">2019-06-12   13:51:30.0</a></b><i class="ago" id="ago20">5hr 07min ago</i></td><td class="tabev1">9.75 </td><td class="tabev2">N  </td><td class="tabev1">84.39 </td><td class="tabev2">W  </td><td class="tabev3">46</td><td class="tabev5" id="magtyp20"> M</td><td class="tabev2">3.3</td><td class="tb_region" id="reg20"> COSTA RICA</td><td class="comment updatetimeno" id="upd20" style="text-align:right;">2019-06-12 14:15</td></tr>,
#  <tr class="ligne1 normal" id="770890" onclick="go_details(event,770890);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770890">2019-06-12   11:43:35.4</a></b><i class="ago" id="ago22">7hr 15min ago</i></td><td class="tabev1">40.11 </td><td class="tabev2">N  </td><td class="tabev1">122.16 </td><td class="tabev2">W  </td><td class="tabev3">29</td><td class="tabev5" id="magtyp22">Md</td><td class="tabev2">2.6</td><td class="tb_region" id="reg22"> NORTHERN CALIFORNIA</td><td class="comment updatetimeno" id="upd22" style="text-align:right;">2019-06-12 18:17</td></tr>,
#  <tr class="ligne1 normal" id="770887" onclick="go_details(event,770887);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770887">2019-06-12   10:35:07.5</a></b><i class="ago" id="ago24">8hr 23min ago</i></td><td class="tabev1">38.24 </td><td class="tabev2">N  </td><td class="tabev1">141.72 </td><td class="tabev2">E  </td><td class="tabev3">45</td><td class="tabev5" id="magtyp24">mb</td><td class="tabev2">4.7</td><td class="tb_region" id="reg24"> NEAR EAST COAST OF HONSHU, JAPAN</td><td class="comment updatetimeno" id="upd24" style="text-align:right;">2019-06-12 14:55</td></tr>,
#  <tr class="ligne1 normal" id="770894" onclick="go_details(event,770894);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770894">2019-06-12   09:59:13.0</a></b><i class="ago" id="ago26">8hr 59min ago</i></td><td class="tabev1">18.14 </td><td class="tabev2">N  </td><td class="tabev1">103.46 </td><td class="tabev2">W  </td><td class="tabev3">4</td><td class="tabev5" id="magtyp26"> M</td><td class="tabev2">3.7</td><td class="tb_region" id="reg26"> OFFSHORE MICHOACAN, MEXICO</td><td class="comment updatetimeno" id="upd26" style="text-align:right;">2019-06-12 13:02</td></tr>,
#  <tr class="ligne1 normal" id="770879" onclick="go_details(event,770879);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770879">2019-06-12   09:32:39.0</a></b><i class="ago" id="ago28">9hr 26min ago</i></td><td class="tabev1">2.62 </td><td class="tabev2">S  </td><td class="tabev1">79.66 </td><td class="tabev2">W  </td><td class="tabev3">21</td><td class="tabev5" id="magtyp28"> M</td><td class="tabev2">3.7</td><td class="tb_region" id="reg28"> NEAR COAST OF ECUADOR</td><td class="comment updatetimeno" id="upd28" style="text-align:right;">2019-06-12 09:35</td></tr>,
#  <tr class="ligne1 normal" id="770880" onclick="go_details(event,770880);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770880">2019-06-12   09:13:19.4</a></b><i class="ago" id="ago30">9hr 45min ago</i></td><td class="tabev1">3.43 </td><td class="tabev2">S  </td><td class="tabev1">102.75 </td><td class="tabev2">W  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp30">mb</td><td class="tabev2">4.4</td><td class="tb_region" id="reg30"> CENTRAL EAST PACIFIC RISE</td><td class="comment updatetimeno" id="upd30" style="text-align:right;">2019-06-12 14:55</td></tr>,
#  <tr class="ligne1 normal" id="770892" onclick="go_details(event,770892);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770892">2019-06-12   08:49:53.5</a></b><i class="ago" id="ago32">10hr 08min ago</i></td><td class="tabev1">19.03 </td><td class="tabev2">N  </td><td class="tabev1">68.35 </td><td class="tabev2">W  </td><td class="tabev3">110</td><td class="tabev5" id="magtyp32">Md</td><td class="tabev2">3.0</td><td class="tb_region" id="reg32"> DOMINICAN REPUBLIC REGION</td><td class="comment updatetimeno" id="upd32" style="text-align:right;">2019-06-12 11:56</td></tr>,
#  <tr class="ligne1 normal" id="770877" onclick="go_details(event,770877);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770877">2019-06-12   08:45:32.5</a></b><i class="ago" id="ago34">10hr 13min ago</i></td><td class="tabev1">41.77 </td><td class="tabev2">N  </td><td class="tabev1">43.12 </td><td class="tabev2">E  </td><td class="tabev3">1</td><td class="tabev5" id="magtyp34">ML</td><td class="tabev2">3.3</td><td class="tb_region" id="reg34"> GEORGIA (SAK'ART'VELO)</td><td class="comment updatetimeno" id="upd34" style="text-align:right;">2019-06-12 09:35</td></tr>,
#  <tr class="ligne1 normal" id="770870" onclick="go_details(event,770870);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770870">2019-06-12   08:18:24.7</a></b><i class="ago" id="ago36">10hr 40min ago</i></td><td class="tabev1">41.63 </td><td class="tabev2">N  </td><td class="tabev1">12.81 </td><td class="tabev2">E  </td><td class="tabev3">9</td><td class="tabev5" id="magtyp36">ML</td><td class="tabev2">2.0</td><td class="tb_region" id="reg36"> SOUTHERN ITALY</td><td class="comment updatetimeno" id="upd36" style="text-align:right;">2019-06-12 08:27</td></tr>,
#  <tr class="ligne1 normal" id="770901" onclick="go_details(event,770901);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770901">2019-06-12   08:17:30.0</a></b><i class="ago" id="ago38">10hr 41min ago</i></td><td class="tabev1">16.60 </td><td class="tabev2">N  </td><td class="tabev1">98.56 </td><td class="tabev2">W  </td><td class="tabev3">11</td><td class="tabev5" id="magtyp38"> M</td><td class="tabev2">3.5</td><td class="tb_region" id="reg38"> GUERRERO, MEXICO</td><td class="comment updatetimeno" id="upd38" style="text-align:right;">2019-06-12 13:02</td></tr>,
#  <tr class="ligne1 normal" id="770866" onclick="go_details(event,770866);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770866">2019-06-12   08:08:34.1</a></b><i class="ago" id="ago40">10hr 50min ago</i></td><td class="tabev1">20.01 </td><td class="tabev2">N  </td><td class="tabev1">155.94 </td><td class="tabev2">W  </td><td class="tabev3">11</td><td class="tabev5" id="magtyp40">Md</td><td class="tabev2">2.2</td><td class="tb_region" id="reg40"> HAWAII REGION, HAWAII</td><td class="comment updatetimeno" id="upd40" style="text-align:right;">2019-06-12 08:11</td></tr>,
#  <tr class="ligne1 normal" id="770868" onclick="go_details(event,770868);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770868">2019-06-12   08:02:27.0</a></b><i class="ago" id="ago42">10hr 56min ago</i></td><td class="tabev1">31.13 </td><td class="tabev2">S  </td><td class="tabev1">71.72 </td><td class="tabev2">W  </td><td class="tabev3">34</td><td class="tabev5" id="magtyp42">ML</td><td class="tabev2">3.6</td><td class="tb_region" id="reg42"> OFFSHORE COQUIMBO, CHILE</td><td class="comment updatetimeno" id="upd42" style="text-align:right;">2019-06-12 08:18</td></tr>,
#  <tr class="ligne1 normal" id="770863" onclick="go_details(event,770863);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770863">2019-06-12   07:36:18.0</a></b><i class="ago" id="ago44">11hr 22min ago</i></td><td class="tabev1">37.40 </td><td class="tabev2">S  </td><td class="tabev1">74.11 </td><td class="tabev2">W  </td><td class="tabev3">19</td><td class="tabev5" id="magtyp44">ML</td><td class="tabev2">3.9</td><td class="tb_region" id="reg44"> OFFSHORE BIO-BIO, CHILE</td><td class="comment updatetimeno" id="upd44" style="text-align:right;">2019-06-12 07:47</td></tr>,
#  <tr class="ligne1 normal" id="770933" onclick="go_details(event,770933);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770933">2019-06-12   07:24:24.0</a></b><i class="ago" id="ago46">11hr 34min ago</i></td><td class="tabev1">19.48 </td><td class="tabev2">N  </td><td class="tabev1">69.81 </td><td class="tabev2">W  </td><td class="tabev3">16</td><td class="tabev5" id="magtyp46"> M</td><td class="tabev2">3.2</td><td class="tb_region" id="reg46"> DOMINICAN REPUBLIC REGION</td><td class="comment updatetimeno" id="upd46" style="text-align:right;">2019-06-12 17:55</td></tr>,
#  <tr class="ligne1 normal" id="770904" onclick="go_details(event,770904);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=770904">2019-06-12   07:06:46.0</a></b><i class="ago" id="ago48">11hr 51min ago</i></td><td class="tabev1">16.26 </td><td class="tabev2">N  </td><td class="tabev1">98.01 </td><td class="tabev2">W  </td><td class="tabev3">6</td><td class="tabev5" id="magtyp48"> M</td><td class="tabev2">3.3</td><td class="tb_region" id="reg48"> OAXACA, MEXICO</td><td class="comment updatetimeno" id="upd48" style="text-align:right;">2019-06-12 13:03</td></tr>]

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

ea_html = requests.get(url).text
soup_ea = BeautifulSoup(ea_html, "html.parser")

data = []
table = soup_ea.find_all('tr', class_= 'normal')

for td in table:
    #print(td)
    temp_fecha = td.contents[3].find('a').text
    temp_fecha = temp_fecha.split()
    fecha = temp_fecha[0]
    hora = temp_fecha[1]
    
    latitud = td.contents[4].text + td.contents[5].text
    longitud = td.contents[6].text + td.contents[7].text
    region = td.contents[11].text
    
    data.append([fecha, hora, latitud, longitud, region])


terremotos = pd.DataFrame(data, columns = ['date', 'time', 'latitude', 'longitude','region'])
terremotos.head(20)
# Out:
#           date        time   latitude   longitude  \
# 0   2019-06-12  18:47:06.0   6.43 S    131.40 E
# 1   2019-06-12  18:46:09.6  37.76 N     35.53 E
# 2   2019-06-12  18:42:41.9  38.81 N     26.48 E
# 3   2019-06-12  18:16:20.4  37.54 N    117.92 W
# 4   2019-06-12  18:02:58.3  34.43 N     45.62 E
# 5   2019-06-12  17:25:24.0  14.39 N     93.20 W
# 6   2019-06-12  17:17:23.0  30.38 S    117.75 E
# 7   2019-06-12  17:14:00.1  40.62 N     23.41 E
# 8   2019-06-12  17:07:55.9  36.86 N      3.61 E
# 9   2019-06-12  16:52:04.2  19.23 N    155.40 W
# 10  2019-06-12  16:44:38.6   8.88 S    124.18 E
# 11  2019-06-12  16:41:36.0   0.26 S    119.82 E
# 12  2019-06-12  16:33:00.0  21.73 S     68.78 W
# 13  2019-06-12  16:24:13.4  19.23 N    155.40 W
# 14  2019-06-12  16:22:58.8  40.49 N     20.82 E
# 15  2019-06-12  16:04:09.4  61.52 N    149.92 W
# 16  2019-06-12  15:50:37.8  38.80 N     15.75 E
# 17  2019-06-12  15:42:58.0  31.87 S     70.11 W
# 18  2019-06-12  15:28:01.9  37.28 N    115.22 W
# 19  2019-06-12  15:19:47.4  38.54 N     44.32 E
#
#                                region
# 0     KEP. TANIMBAR REGION, INDONESIA
# 1                      CENTRAL TURKEY
# 2    NEAR THE COAST OF WESTERN TURKEY
# 3                              NEVADA
# 4             IRAN-IRAQ BORDER REGION
# 5            OFFSHORE CHIAPAS, MEXICO
# 6                   WESTERN AUSTRALIA
# 7                              GREECE
# 8                    NORTHERN ALGERIA
# 9            ISLAND OF HAWAII, HAWAII
# 10          KEPULAUAN ALOR, INDONESIA
# 11      MINAHASA, SULAWESI, INDONESIA
# 12                 ANTOFAGASTA, CHILE
# 13           ISLAND OF HAWAII, HAWAII
# 14                            ALBANIA
# 15                    SOUTHERN ALASKA
# 16                      SICILY, ITALY
# 17                SAN JUAN, ARGENTINA
# 18                             NEVADA
# 19          TURKEY-IRAN BORDER REGION
