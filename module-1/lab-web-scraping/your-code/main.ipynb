# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
with open ("github_trending", "w") as github_trending_file:
    github_trending_file.write(response.text)

# %%
#ol class="list-style-none"
lines_container = soup.find("ol", {'class': 'list-style-none'})
lines_container
# Out:
# <ol class="list-style-none">
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-TrillCyborg">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-TrillCyborg" style="width: 16px;">1</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=2574923" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/TrillCyborg"><img alt="@TrillCyborg" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/2574923?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/TrillCyborg">
#                           TrillCyborg
#                             <span class="text-gray text-bold">
#                               (Jason Werner)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/TrillCyborg/fullstack">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="fullstack">
#       fullstack
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     React/ApolloGraphQL/Node/Mongo demo written in Typescript
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-0voice">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-0voice" style="width: 16px;">2</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/0voice/hovercard" href="/0voice"><img alt="@0voice" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/43104160?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/0voice">
#                           0voice
#                             <span class="text-gray text-bold">
#                               (0voice)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/0voice/from_coder_to_expert">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="from_coder_to_expert">
#       from_coder_to_expert
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     2019年最新总结，从程序员到CTO，从专业走向卓越，分享大牛企业内部pdf与PPT
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2"></div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-rasbt">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-rasbt" style="width: 16px;">3</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=5618407" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/rasbt"><img alt="@rasbt" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/5618407?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/rasbt">
#                           rasbt
#                             <span class="text-gray text-bold">
#                               (Sebastian Raschka)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/rasbt/python-machine-learning-book">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="python-machine-learning-book">
#       python-machine-learning-book
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     The "Python Machine Learning (1st edition)" book code repository and info resource
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-microsoft">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-microsoft" style="width: 16px;">4</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/microsoft/hovercard" href="/microsoft"><img alt="@microsoft" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/6154722?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/microsoft">
#                           microsoft
#                             <span class="text-gray text-bold">
#                               (Microsoft)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/microsoft/vscode">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="vscode">
#       vscode
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     Visual Studio Code
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2"></div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-imhuster">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-imhuster" style="width: 16px;">5</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=13541953" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/imhuster"><img alt="@imhuster" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/13541953?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/imhuster">
#                           imhuster
#                             <span class="text-gray text-bold">
#                               (Aven Liu)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/imhuster/Enterprise-Registration-Data-of-Chinese-Mainland">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="Enterprise-Registration-Data-of-Chinese-Mainland">
#       Enterprise-Registration-Data-of-Chinese-Mainland
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     中国大陆 31 个省份1978 年至 2019 年一千多万工商企业注册信息，包含企业名称、注册地址、统一社会信用代码、地区、注册日期、经营范围、法人代表、注册资金、企业类型等详细资料。This repository is an dataset of over 10,000,000 enterprise registration data of 31 provinces in Chinese mainland from 1978 to 2019.【工商大数据】、【企业信息】、【enterprise registration data】。
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-jackfrued">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-jackfrued" style="width: 16px;">6</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=7474657" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/jackfrued"><img alt="@jackfrued" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/7474657?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/jackfrued">
#                           jackfrued
#                             <span class="text-gray text-bold">
#                               (骆昊)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/jackfrued/Python-100-Days">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="Python-100-Days">
#       Python-100-Days
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     Python - 100天从新手到大师
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-sfyc23">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-sfyc23" style="width: 16px;">7</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=7067207" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/sfyc23"><img alt="@sfyc23" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/7067207?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/sfyc23">
#                           sfyc23
#                             <span class="text-gray text-bold">
#                               ( Thunder Bouble)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/sfyc23/EverydayWechat">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="EverydayWechat">
#       EverydayWechat
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     每日自动给女朋友发微信暖心话。
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-Juanpe">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-Juanpe" style="width: 16px;">8</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=1409041" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/Juanpe"><img alt="@Juanpe" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/1409041?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/Juanpe">
#                           Juanpe
#                             <span class="text-gray text-bold">
#                               (Juanpe Catalán)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/Juanpe/SkeletonView">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="SkeletonView">
#       SkeletonView
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     An elegant way to show users that something is happening and also prepare them to which contents he is waiting
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-apache">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-apache" style="width: 16px;">9</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/apache/hovercard" href="/apache"><img alt="@apache" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/47359?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/apache">
#                           apache
#                             <span class="text-gray text-bold">
#                               (The Apache Software Foundation)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/apache/incubator-echarts">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="incubator-echarts">
#       incubator-echarts
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     A powerful, interactive charting and visualization library for browser
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2"></div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-MisterBooo">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-MisterBooo" style="width: 16px;">10</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=15308811" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/MisterBooo"><img alt="@MisterBooo" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/15308811?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/MisterBooo">
#                           MisterBooo
#                             <span class="text-gray text-bold">
#                               (程序员吴师兄)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/MisterBooo/LeetCodeAnimation">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="LeetCodeAnimation">
#       LeetCodeAnimation
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     Demonstrate all the questions on LeetCode in the form of animation.（用动画的形式呈现解LeetCode题目的思路）
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-jlevy">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-jlevy" style="width: 16px;">11</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=2058167" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/jlevy"><img alt="@jlevy" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/2058167?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/jlevy">
#                           jlevy
#                             <span class="text-gray text-bold">
#                               (Joshua Levy)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/jlevy/the-art-of-command-line">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="the-art-of-command-line">
#       the-art-of-command-line
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     Master the command line, in one page
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-geohot">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-geohot" style="width: 16px;">12</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=72895" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/geohot"><img alt="@geohot" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/72895?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/geohot">
#                           geohot
#                             <span class="text-gray text-bold">
#                               (George Hotz)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/geohot/qira">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="qira">
#       qira
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     QEMU Interactive Runtime Analyser
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-ngosang">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-ngosang" style="width: 16px;">13</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=10577978" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/ngosang"><img alt="@ngosang" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/10577978?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/ngosang">
#                           ngosang
#                             <span class="text-gray text-bold">
#                               (Diego Heras)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/ngosang/trackerslist">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="trackerslist">
#       trackerslist
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     Updated list of public BitTorrent trackers
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-CarGuo">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-CarGuo" style="width: 16px;">14</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=10770362" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/CarGuo"><img alt="@CarGuo" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/10770362?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/CarGuo">
#                           CarGuo
#                             <span class="text-gray text-bold">
#                               (Shuyu Guo)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/CarGuo/GSYVideoPlayer">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="GSYVideoPlayer">
#       GSYVideoPlayer
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     视频播放器（IJKplayer、ExoPlayer、MediaPlayer），HTTPS支持，支持弹幕，支持滤镜、水印、gif截图，片头广告、中间广告，多个同时播放，支持基本的拖动，声音、亮度调节，支持边播边缓存，支持视频本身自带rotation的旋转（90,270之类），重力旋转与手动旋转的同步支持，支持列表播放 ，直接添加控件为封面，列表全屏动画，视频加载速度，列表小窗口支持拖动，动画效果，调整比例，多分辨率切换，支持切换播放器，进度条小窗口预览，列表切换详情页面无缝播放，其他一些小动画效果，rtsp、concat、mpeg。项目解析：
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-google">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-google" style="width: 16px;">15</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/google/hovercard" href="/google"><img alt="@google" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/1342004?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/google">
#                           google
#                             <span class="text-gray text-bold">
#                               (Google)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/google/material-design-icons">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="material-design-icons">
#       material-design-icons
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     Material Design icons by Google
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2"></div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-tensorflow">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-tensorflow" style="width: 16px;">16</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/tensorflow/hovercard" href="/tensorflow"><img alt="@tensorflow" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/15658638?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/tensorflow">
#                           tensorflow
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/tensorflow/tensorflow">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="tensorflow">
#       tensorflow
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     An Open Source Machine Learning Framework for Everyone
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2"></div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-kylelobo">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-kylelobo" style="width: 16px;">17</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=25124502" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/kylelobo"><img alt="@kylelobo" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/25124502?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/kylelobo">
#                           kylelobo
#                             <span class="text-gray text-bold">
#                               (Kyle Lobo)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/kylelobo/The-Documentation-Compendium">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="The-Documentation-Compendium">
#       The-Documentation-Compendium
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
# <g-emoji alias="loudspeaker" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f4e2.png">📢</g-emoji> Various README templates &amp; tips on writing high-quality documentation that people want to read.
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-facebook">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-facebook" style="width: 16px;">18</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/facebook/hovercard" href="/facebook"><img alt="@facebook" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/69631?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/facebook">
#                           facebook
#                             <span class="text-gray text-bold">
#                               (Facebook)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/facebook/react">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="react">
#       react
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     A declarative, efficient, and flexible JavaScript library for building user interfaces.
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2"></div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-SimpleBoilerplates">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-SimpleBoilerplates" style="width: 16px;">19</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/SimpleBoilerplates/hovercard" href="/SimpleBoilerplates"><img alt="@SimpleBoilerplates" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/47558590?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/SimpleBoilerplates">
#                           SimpleBoilerplates
#                             <span class="text-gray text-bold">
#                               (Simple Boilerplates)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/SimpleBoilerplates/SwiftUI-Cheat-Sheet">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="SwiftUI-Cheat-Sheet">
#       SwiftUI-Cheat-Sheet
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     SwiftUI Cheat Sheet
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2"></div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-d2l-ai">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-d2l-ai" style="width: 16px;">20</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/d2l-ai/hovercard" href="/d2l-ai"><img alt="@d2l-ai" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/43974506?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/d2l-ai">
#                           d2l-ai
#                             <span class="text-gray text-bold">
#                               (Dive into Deep Learning)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/d2l-ai/d2l-zh">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="d2l-zh">
#       d2l-zh
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     《动手学深度学习》，英文版即伯克利深度学习（STAT 157，2019春）教材。面向中文读者、能运行、可讨论。
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2"></div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-CyC2018">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-CyC2018" style="width: 16px;">21</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=36260787" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/CyC2018"><img alt="@CyC2018" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/36260787?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/CyC2018">
#                           CyC2018
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/CyC2018/CS-Notes">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="CS-Notes">
#       CS-Notes
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
# <g-emoji alias="books" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f4da.png">📚</g-emoji> 技术面试必备基础知识、Leetcode 题解、Java、C++、Python、后端面试、操作系统、计算机网络、系统设计
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-vuejs">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-vuejs" style="width: 16px;">22</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/vuejs/hovercard" href="/vuejs"><img alt="@vuejs" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/6128107?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/vuejs">
#                           vuejs
#                             <span class="text-gray text-bold">
#                               (vuejs)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/vuejs/vue">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="vue">
#       vue
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
# <g-emoji alias="vulcan_salute" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f596.png">🖖</g-emoji> Vue.js is a progressive, incrementally-adoptable JavaScript framework for building UI on the web.
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2"></div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-alibaba">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-alibaba" style="width: 16px;">23</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="organization" data-hovercard-url="/orgs/alibaba/hovercard" href="/alibaba"><img alt="@alibaba" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/1961952?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/alibaba">
#                           alibaba
#                             <span class="text-gray text-bold">
#                               (Alibaba)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/alibaba/fastjson">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="fastjson">
#       fastjson
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
# <g-emoji alias="bullettrain_side" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f684.png">🚄</g-emoji> A fast JSON parser/generator for Java. (Aliyun Data Lake Analytics <a href="https://www.aliyun.com/product/datalakeanalytics" rel="nofollow">https://www.aliyun.com/product/datalakeanalytics</a> powered by fastjson )
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2"></div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-Snailclimb">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-Snailclimb" style="width: 16px;">24</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=29880145" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/Snailclimb"><img alt="@Snailclimb" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/29880145?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/Snailclimb">
#                           Snailclimb
#                             <span class="text-gray text-bold">
#                               (SnailClimb)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/Snailclimb/JavaGuide">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="JavaGuide">
#       JavaGuide
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     【Java学习+面试指南】 一份涵盖大部分Java程序员所需要掌握的核心知识。
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-wwenj">
# <div class="d-flex">
# <a class="text-center text-small text-gray mx-2" href="#pa-wwenj" style="width: 16px;">25</a>
# <div class="mx-2">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=26293313" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/wwenj"><img alt="@wwenj" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/26293313?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="mx-2">
# <h2 class="f3 text-normal">
# <a href="/wwenj">
#                           wwenj
#                             <span class="text-gray text-bold">
#                               (王文健)
#                             </span>
# </a> </h2>
# <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/wwenj/tripRecord">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="repo-snipit-name css-truncate-target">
# <span class="repo" title="tripRecord">
#       tripRecord
#     </span>
# </span>
# <span class="repo-snipit-description css-truncate-target">
#     咔咔出行——解决出行问题基于高德地图API，Vue，Express实现的移动端全栈webapp
#   </span>
# </a>
# </div>
# </div>
# <div class="mx-2 ml-6 ml-sm-2">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"8563:2009F:89C1007:D3C7183:5CFF5FB4","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="7fda2565cbaa4365a33dbf66cb5a466afa6321a228ea8e1756a75c750d753a73" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </li>
# </ol>

# %%
#lines = lines_container.find_all("a",{"role":"link"})
lines = lines_container.find_all("h2",{'class':'f3 text-normal'})
lines
# Out:
# [<h2 class="f3 text-normal">
#  <a href="/TrillCyborg">
#                            TrillCyborg
#                              <span class="text-gray text-bold">
#                                (Jason Werner)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/0voice">
#                            0voice
#                              <span class="text-gray text-bold">
#                                (0voice)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/rasbt">
#                            rasbt
#                              <span class="text-gray text-bold">
#                                (Sebastian Raschka)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/microsoft">
#                            microsoft
#                              <span class="text-gray text-bold">
#                                (Microsoft)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/imhuster">
#                            imhuster
#                              <span class="text-gray text-bold">
#                                (Aven Liu)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/jackfrued">
#                            jackfrued
#                              <span class="text-gray text-bold">
#                                (骆昊)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/sfyc23">
#                            sfyc23
#                              <span class="text-gray text-bold">
#                                ( Thunder Bouble)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/Juanpe">
#                            Juanpe
#                              <span class="text-gray text-bold">
#                                (Juanpe Catalán)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/apache">
#                            apache
#                              <span class="text-gray text-bold">
#                                (The Apache Software Foundation)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/MisterBooo">
#                            MisterBooo
#                              <span class="text-gray text-bold">
#                                (程序员吴师兄)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/jlevy">
#                            jlevy
#                              <span class="text-gray text-bold">
#                                (Joshua Levy)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/geohot">
#                            geohot
#                              <span class="text-gray text-bold">
#                                (George Hotz)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/ngosang">
#                            ngosang
#                              <span class="text-gray text-bold">
#                                (Diego Heras)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/CarGuo">
#                            CarGuo
#                              <span class="text-gray text-bold">
#                                (Shuyu Guo)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/google">
#                            google
#                              <span class="text-gray text-bold">
#                                (Google)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/tensorflow">
#                            tensorflow
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/kylelobo">
#                            kylelobo
#                              <span class="text-gray text-bold">
#                                (Kyle Lobo)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/facebook">
#                            facebook
#                              <span class="text-gray text-bold">
#                                (Facebook)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/SimpleBoilerplates">
#                            SimpleBoilerplates
#                              <span class="text-gray text-bold">
#                                (Simple Boilerplates)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/d2l-ai">
#                            d2l-ai
#                              <span class="text-gray text-bold">
#                                (Dive into Deep Learning)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/CyC2018">
#                            CyC2018
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/vuejs">
#                            vuejs
#                              <span class="text-gray text-bold">
#                                (vuejs)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/alibaba">
#                            alibaba
#                              <span class="text-gray text-bold">
#                                (Alibaba)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/Snailclimb">
#                            Snailclimb
#                              <span class="text-gray text-bold">
#                                (SnailClimb)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/wwenj">
#                            wwenj
#                              <span class="text-gray text-bold">
#                                (王文健)
#                              </span>
#  </a> </h2>]

# %%
lines_href = [line.get('text-gray text-bold') for line in lines]
lines_href
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise

# %%
#your code
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

url = 'https://github.com/trending/python?since=daily'
with open ("github_trending_2", "w") as github_trending_2_file:
    github_trending_2_file.write(response.text)
    
repos_container = soup.find("ol", {"class":"repo-list"})
container = repos_container.find_all("h3")

repos_list =[] 
for repos in container:
    repo_name = repos.text.replace("/n", "")
# Out:
# [<h3>
#  <a href="/sfyc23/EverydayWechat">
#  <span class="text-normal">sfyc23 / </span>EverydayWechat
#  </a> </h3>, <h3>
#  <a href="/d2l-ai/d2l-zh">
#  <span class="text-normal">d2l-ai / </span>d2l-zh
#  </a> </h3>, <h3>
#  <a href="/TheAlgorithms/Python">
#  <span class="text-normal">TheAlgorithms / </span>Python
#  </a> </h3>, <h3>
#  <a href="/anned20/begoneads">
#  <span class="text-normal">anned20 / </span>begoneads
#  </a> </h3>, <h3>
#  <a href="/pytorch/hub">
#  <span class="text-normal">pytorch / </span>hub
#  </a> </h3>, <h3>
#  <a href="/ConnorJL/GPT2">
#  <span class="text-normal">ConnorJL / </span>GPT2
#  </a> </h3>, <h3>
#  <a href="/google-research/football">
#  <span class="text-normal">google-research / </span>football
#  </a> </h3>, <h3>
#  <a href="/realsirjoe/instagram-scraper">
#  <span class="text-normal">realsirjoe / </span>instagram-scraper
#  </a> </h3>, <h3>
#  <a href="/Roujack/mathAI">
#  <span class="text-normal">Roujack / </span>mathAI
#  </a> </h3>, <h3>
#  <a href="/donnemartin/system-design-primer">
#  <span class="text-normal">donnemartin / </span>system-design-primer
#  </a> </h3>, <h3>
#  <a href="/shengqiangzhang/examples-of-web-crawlers">
#  <span class="text-normal">shengqiangzhang / </span>examples-of-web-crawlers
#  </a> </h3>, <h3>
#  <a href="/tensorflow/models">
#  <span class="text-normal">tensorflow / </span>models
#  </a> </h3>, <h3>
#  <a href="/StevenBlack/hosts">
#  <span class="text-normal">StevenBlack / </span>hosts
#  </a> </h3>, <h3>
#  <a href="/apachecn/AiLearning">
#  <span class="text-normal">apachecn / </span>AiLearning
#  </a> </h3>, <h3>
#  <a href="/OakwoodAI/Automagica">
#  <span class="text-normal">OakwoodAI / </span>Automagica
#  </a> </h3>, <h3>
#  <a href="/keras-team/keras">
#  <span class="text-normal">keras-team / </span>keras
#  </a> </h3>, <h3>
#  <a href="/tensorflow/text">
#  <span class="text-normal">tensorflow / </span>text
#  </a> </h3>, <h3>
#  <a href="/vinta/awesome-python">
#  <span class="text-normal">vinta / </span>awesome-python
#  </a> </h3>, <h3>
#  <a href="/wangzheng0822/algo">
#  <span class="text-normal">wangzheng0822 / </span>algo
#  </a> </h3>, <h3>
#  <a href="/google-research/bert">
#  <span class="text-normal">google-research / </span>bert
#  </a> </h3>, <h3>
#  <a href="/machinelearningmindset/machine-learning-course">
#  <span class="text-normal">machinelearningmindset / </span>machine-learning-course
#  </a> </h3>, <h3>
#  <a href="/CorruptComputer/ProtonDB-to-Steam-Library">
#  <span class="text-normal">CorruptComputer / </span>ProtonDB-to-Steam-Library
#  </a> </h3>, <h3>
#  <a href="/likaixiang/EverydayWechat">
#  <span class="text-normal">likaixiang / </span>EverydayWechat
#  </a> </h3>, <h3>
#  <a href="/quantumblacklabs/kedro">
#  <span class="text-normal">quantumblacklabs / </span>kedro
#  </a> </h3>, <h3>
#  <a href="/django/django">
#  <span class="text-normal">django / </span>django
#  </a> </h3>]

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
