# %%
import urllib.request as urllib2
import json
import csv
import time
import datetime
import pandas as pd

# %%
"""
Simple Program to help you get started with Google's APIs
"""
import urllib.request, json
#Google MapsDdirections API endpoint
endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'
api_key = 'AIzaSyDUnpkvkB-v5j9whLjE7b_l1XfzzipLWfo'
#Asks the user to input Where they are and where they want to go.
origin = input('Where are you?: ').replace(' ','+')
destination = input('Where do you want to go?: ').replace(' ','+')
#Building the URL for the request
nav_request = 'origin={}&destination={}&key={}'.format(origin,destination,api_key)
request = endpoint + nav_request
#Sends the request and reads the response.
response = urllib.request.urlopen(request).read()
#Loads response as JSON
directions = json.loads(response)
directions
#Calle Enrique Granados 8  Calle Miguel Angel 17
# Out:
# Where are you?: Calle Francisco Sancha 42
# Where do you want to go?: Calle Miguel Angel 17
# {'geocoded_waypoints': [{'geocoder_status': 'OK',
#    'place_id': 'ChIJ4_BNSnspQg0Rhj-j163efxQ',
#    'types': ['street_address']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJZe00C-0oQg0RqzkLdudv3kg',
#    'types': ['street_address']}],
#  'routes': [{'bounds': {'northeast': {'lat': 40.4913431, 'lng': -3.6854964},
#     'southwest': {'lat': 40.435923, 'lng': -3.6991106}},
#    'copyrights': 'Map data ©2019 Inst. Geogr. Nacional',
#    'legs': [{'distance': {'text': '7.9 km', 'value': 7874},
#      'duration': {'text': '15 mins', 'value': 895},
#      'end_address': 'Calle de Miguel Ángel, 17, 28010 Madrid, Spain',
#      'end_location': {'lat': 40.435923, 'lng': -3.691253},
#      'start_address': 'Calle Francisco Sancha, 42, 28034 Madrid, Spain',
#      'start_location': {'lat': 40.4882966, 'lng': -3.6931565},
#      'steps': [{'distance': {'text': '81 m', 'value': 81},
#        'duration': {'text': '1 min', 'value': 16},
#        'end_location': {'lat': 40.4883073, 'lng': -3.6921966},
#        'html_instructions': 'Head <b>east</b> on <b>Calle Francisco Sancha</b> toward <b>Calle Salcedo</b>',
#        'polyline': {'points': '{zbvFfipU?q@AmC'},
#        'start_location': {'lat': 40.4882966, 'lng': -3.6931565},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.3 km', 'value': 271},
#        'duration': {'text': '2 mins', 'value': 104},
#        'end_location': {'lat': 40.49074239999999, 'lng': -3.6923184},
#        'html_instructions': 'Turn <b>left</b> onto <b>Calle Salcedo</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': '}zbvFfcpUa@?gAB{B?sBBC?gABc@@[H'},
#        'start_location': {'lat': 40.4883073, 'lng': -3.6921966},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.5 km', 'value': 547},
#        'duration': {'text': '1 min', 'value': 77},
#        'end_location': {'lat': 40.4900551, 'lng': -3.698664},
#        'html_instructions': 'Turn <b>left</b> onto <b>Av del Cardenal Herrera Oria</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'cjcvF~cpUKNFVBLBNBP@P@P@N@P?TBx@Bh@?J@\\Bj@Br@@^Bj@Bl@Dr@@R?HPdELjCDn@B`@BZ@F?H@HBTBT@NRfA@H@D@D?D?DAB'},
#        'start_location': {'lat': 40.49074239999999, 'lng': -3.6923184},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.4 km', 'value': 385},
#        'duration': {'text': '1 min', 'value': 40},
#        'end_location': {'lat': 40.4895061, 'lng': -3.698174},
#        'html_instructions': 'Turn <b>right</b> onto the ramp to <b>M-30</b>/<wbr/><b>A-1</b>/<wbr/><b>Burgos</b>',
#        'maneuver': 'ramp-right',
#        'polyline': {'points': '{ecvFrkqUKRA@A@A@A@EBIDMBq@PUFe@JUDK@I@A?I?G?C?EACACCCCAACEACAE?G?E?G@E@IBCBC@ABCFCFARC@?@A@?@AhBSRCFAXEDA\\GJCTEb@I@ABCJCJCBA@??A@C?A?E'},
#        'start_location': {'lat': 40.4900551, 'lng': -3.698664},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.7 km', 'value': 682},
#        'duration': {'text': '1 min', 'value': 33},
#        'end_location': {'lat': 40.485208, 'lng': -3.6929501},
#        'html_instructions': 'Merge onto <b>M-607</b>',
#        'maneuver': 'merge',
#        'polyline': {'points': 'mbcvFphqU`@GVIPEj@Qf@OVKRIVKPIVMd@Yh@]DCJIPMRQRQTWZ[RU\\e@^i@^k@NWLULUJUb@cALa@To@L_@`@uANi@XaABMBIFUPk@H[FY'},
#        'start_location': {'lat': 40.4895061, 'lng': -3.698174},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.4 km', 'value': 408},
#        'duration': {'text': '1 min', 'value': 24},
#        'end_location': {'lat': 40.4834503, 'lng': -3.6887439},
#        'html_instructions': "Take the exit toward <b>P' Castellana</b>",
#        'maneuver': 'ramp-right',
#        'polyline': {'points': 'qgbvF|gpUBAB??A@AJWNe@To@J]XcATu@j@mB@CTy@HYRm@^oAX_AFQNe@\\iATw@'},
#        'start_location': {'lat': 40.485208, 'lng': -3.6929501},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.4 km', 'value': 381},
#        'duration': {'text': '1 min', 'value': 25},
#        'end_location': {'lat': 40.4812972, 'lng': -3.6855542},
#        'html_instructions': 'Keep <b>right</b> at the fork to continue toward <b>Paseo de la Castellana</b>',
#        'maneuver': 'fork-right',
#        'polyline': {'points': 'q|avFrmoUBA@C@CBGPm@Vw@DOTq@Nk@Vy@V_APk@DMFOBIHMHUJUDIDKLQNUDEBEDEDEHGBAHEFCFCPGRGFALCJCHAHAFAJA'},
#        'start_location': {'lat': 40.4834503, 'lng': -3.6887439},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '70 m', 'value': 70},
#        'duration': {'text': '1 min', 'value': 5},
#        'end_location': {'lat': 40.4806731, 'lng': -3.6854964},
#        'html_instructions': 'Keep <b>left</b> to continue toward <b>Paseo de la Castellana</b>',
#        'maneuver': 'keep-left',
#        'polyline': {'points': 'coavFtynUJADAHAT?XAT@F?B?B?JC'},
#        'start_location': {'lat': 40.4812972, 'lng': -3.6855542},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '4.3 km', 'value': 4333},
#        'duration': {'text': '7 mins', 'value': 432},
#        'end_location': {'lat': 40.4420799, 'lng': -3.6917853},
#        'html_instructions': 'Continue onto <b>Paseo de la Castellana</b><div style="font-size:0.9em">Parts of this road are closed Sundays 9:30 – 11:15 AM</div>',
#        'polyline': {'points': 'ekavFjynUR@NBB?PBNBz@Nj@JPDfARv@LD@|@PtATbAPrAVtATh@J~@PH@j@JNB|@N`APJBb@H@?pAV@?n@Jt@NzAVhBZb@HdARx@NfARnATl@J`APnATz@L`ALXFz@LLDXDb@HVBNB`@B^Bj@BdA?dAJnAPrARPDPDH@HB`@Hh@Pt@Rn@Nr@Lr@HjANjALlAFhBHdADhBNfADhBF|AF`ERvERrDPpERhCLfADfCLrDPxBJd@BvADfADb@BfADf@DhAFb@BfAFdADj@@|AHjBHfDP|AFD?jBJnCLz@BN@F@\\DH@l@Bv@Fp@F`@BN@l@Bb@Bn@Bh@B`BHlCLP@RBX@z@DtBHbBH'},
#        'start_location': {'lat': 40.4806731, 'lng': -3.6854964},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.1 km', 'value': 109},
#        'duration': {'text': '1 min', 'value': 18},
#        'end_location': {'lat': 40.4411086, 'lng': -3.6919841},
#        'html_instructions': 'Keep <b>left</b> to stay on <b>Paseo de la Castellana</b>',
#        'maneuver': 'keep-left',
#        'polyline': {'points': '_zyuFt`pU\\@J@R@h@H^Hx@J'},
#        'start_location': {'lat': 40.4420799, 'lng': -3.6917853},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.4 km', 'value': 396},
#        'duration': {'text': '1 min', 'value': 68},
#        'end_location': {'lat': 40.4378173, 'lng': -3.69123},
#        'html_instructions': 'Continue straight to stay on <b>Paseo de la Castellana</b>',
#        'maneuver': 'straight',
#        'polyline': {'points': '}syuFzapUEJELN?N?@?`@CTC`Be@nBi@pA[VMDCn@Md@KJCPGJCJ?H?J?T@XBT?XE'},
#        'start_location': {'lat': 40.4411086, 'lng': -3.6919841},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.2 km', 'value': 211},
#        'duration': {'text': '1 min', 'value': 53},
#        'end_location': {'lat': 40.435923, 'lng': -3.691253},
#        'html_instructions': 'Slight <b>right</b> onto <b>Calle de Miguel Ángel</b><div style="font-size:0.9em">Destination will be on the right</div>',
#        'maneuver': 'turn-slight-right',
#        'polyline': {'points': 'k_yuFd}oUHD@?@?@?H?`@?@?L?TCF?fC@L?t@?dA?'},
#        'start_location': {'lat': 40.4378173, 'lng': -3.69123},
#        'travel_mode': 'DRIVING'}],
#      'traffic_speed_entry': [],
#      'via_waypoint': []}],
#    'overview_polyline': {'points': '{zbvFfipUA_EiBBoFBkABc@@[HKNFVF\\Db@DhAHlCXjHh@bLFv@b@~CAHMTKHiAZ}AZ]@QGIKCWF[PM^G`CYlCg@^MBG?E`@Gh@O~Bw@fB}@lAy@|@{@n@q@|@oAjAoBn@yAb@qAxAaF`@yAPu@FA\\aApAgElAeEtAoEfAiDX}@bAeDfAsDJYRc@d@}@^g@\\Ut@Wj@Kh@G~@Ed@@JCR@RBhCb@bMzBlU`EtOpCfFx@fCb@hBNpBBtC\\`C`@j@L~Ad@bB\\~BXjALlAFnDNpDTfEN~WlAlYnAjBHpBL|ERlWjA~@JxDV|Lj@`Kd@hARx@JEJELN?N?b@CvBi@`EeA\\QrBe@VCT?n@Dn@ENDz@?\\CtC@zB?'},
#    'summary': 'Paseo de la Castellana',
#    'warnings': [],
#    'waypoint_order': []}],
#  'status': 'OK'}

# %%
distance_meters =  directions['routes'][0]['legs'][0]['distance']['value']
starting_point =  directions['routes'][0]['legs'][0]['start_address']
ending_point =  directions['routes'][0]['legs'][0]['end_address']
duration =  directions['routes'][0]['legs'][0]['duration']
a = {'starting_point' : starting_point, 'ending_point' : ending_point, 'duration': duration}
df = pd.DataFrame.from_dict(data = a, orient = 'index')
df.transpose()
df
# Out:
#                                                               0
# starting_point  Calle Francisco Sancha, 42, 28034 Madrid, Spain
# ending_point     Calle de Miguel Ángel, 17, 28010 Madrid, Spain
# duration                      {'text': '15 mins', 'value': 895}
