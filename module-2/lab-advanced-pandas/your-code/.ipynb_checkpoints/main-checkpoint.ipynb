# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas

import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:

admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:
admissions.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:
admissions.set_index(admissions['Serial No.'],inplace=True)
admissions.head()
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        316          104                  3  3.0  3.5
# 3                    3        322          110                  3  3.5  2.5
# 4                    4        314          103                  2  2.0  3.0
# 5                    5        330          115                  5  4.5  3.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 2           8.00         1             0.72
# 3           8.67         1             0.80
# 4           8.21         0             0.65
# 5           9.34         1             0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:
admissions = admissions.set_index(['GRE Score', 'CGPA'])

# %%
admissions.head()
# Out:
#                 Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# GRE Score CGPA
# 337       9.65           1          118                  4  4.5  4.5
# 316       8.00           2          104                  3  3.0  3.5
# 322       8.67           3          110                  3  3.5  2.5
# 314       8.21           4          103                  2  2.0  3.0
# 330       9.34           5          115                  5  4.5  3.0
#
#                 Research  Chance of Admit
# GRE Score CGPA
# 337       9.65         1             0.92
# 316       8.00         1             0.72
# 322       8.67         1             0.80
# 314       8.21         0             0.65
# 330       9.34         1             0.90

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:
admissions.reset_index(inplace=True)
admissions.head()
# Out:
#    level_0  index  GRE Score  CGPA  Serial No.  TOEFL Score  \
# 0        0      0        337  9.65           1          118
# 1        1      1        316  8.00           2          104
# 2        2      2        322  8.67           3          110
# 3        3      3        314  8.21           4          103
# 4        4      4        330  9.34           5          115
#
#    University Rating  SOP  LOR  Research  Chance of Admit
# 0                  4  4.5  4.5         1             0.92
# 1                  3  3.0  3.5         1             0.72
# 2                  3  3.5  2.5         1             0.80
# 3                  2  2.0  3.0         0             0.65
# 4                  5  4.5  3.0         1             0.90

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:

admissions[admissions['CGPA']>9].count()
# Out:
# level_0              110
# index                110
# GRE Score            110
# CGPA                 110
# Serial No.           110
# TOEFL Score          110
# University Rating    110
# SOP                  110
# LOR                  110
# Research             110
# Chance of Admit      110
# dtype: int64

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:
admissions[(admissions['CGPA']>9) & (admissions['SOP']<3.5)]['Chance of Admit'].mean()
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    # This function takes a column from a dataframe and returns a standardized column by subtracting the column's mean
    # and dividing by the column's standard deviation.
    # Your code here:
    return (col-col.mean())/col.std()

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
admissions['CGPA_std'] = standardize(admissions['CGPA'])
admissions.head()
# Out:
#    level_0  index  GRE Score  CGPA  Serial No.  TOEFL Score  \
# 0        0      0        337  9.65           1          118
# 1        1      1        316  8.00           2          104
# 2        2      2        322  8.67           3          110
# 3        3      3        314  8.21           4          103
# 4        4      4        330  9.34           5          115
#
#    University Rating  SOP  LOR  Research  Chance of Admit  CGPA_std
# 0                  4  4.5  4.5         1             0.92  1.747900
# 1                  3  3.0  3.5         1             0.72 -0.991211
# 2                  3  3.5  2.5         1             0.80  0.121034
# 3                  2  2.0  3.0         0             0.65 -0.642597
# 4                  5  4.5  3.0         1             0.90  1.233279

# %%
admissions['GRE_std'] = standardize(admissions['GRE Score'])
admissions.head()
# Out:
#    level_0  index  GRE Score  CGPA  Serial No.  TOEFL Score  \
# 0        0      0        337  9.65           1          118
# 1        1      1        316  8.00           2          104
# 2        2      2        322  8.67           3          110
# 3        3      3        314  8.21           4          103
# 4        4      4        330  9.34           5          115
#
#    University Rating  SOP  LOR  Research  Chance of Admit  CGPA_std   GRE_std
# 0                  4  4.5  4.5         1             0.92  1.747900  1.753381
# 1                  3  3.0  3.5         1             0.72 -0.991211 -0.063367
# 2                  3  3.5  2.5         1             0.80  0.121034  0.455704
# 3                  2  2.0  3.0         0             0.65 -0.642597 -0.236391
# 4                  5  4.5  3.0         1             0.90  1.233279  1.147798

# %%
admissions['LOR_std'] = standardize(admissions['LOR'])
admissions.head()
# Out:
#    level_0  index  GRE Score  CGPA  Serial No.  TOEFL Score  \
# 0        0      0        337  9.65           1          118
# 1        1      1        316  8.00           2          104
# 2        2      2        322  8.67           3          110
# 3        3      3        314  8.21           4          103
# 4        4      4        330  9.34           5          115
#
#    University Rating  SOP  LOR  Research  Chance of Admit  CGPA_std   GRE_std  \
# 0                  4  4.5  4.5         1             0.92  1.747900  1.753381
# 1                  3  3.0  3.5         1             0.72 -0.991211 -0.063367
# 2                  3  3.5  2.5         1             0.80  0.121034  0.455704
# 3                  2  2.0  3.0         0             0.65 -0.642597 -0.236391
# 4                  5  4.5  3.0         1             0.90  1.233279  1.147798
#
#     LOR_std
# 0  1.191647
# 1  0.076740
# 2 -1.038166
# 3 -0.480713
# 4 -0.480713

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:
admissions['deciding_column'] = admissions.lookup(admissions.index,decision_choice)
admissions.head()
# Out:
#    level_0  index  GRE Score  CGPA  Serial No.  TOEFL Score  \
# 0        0      0        337  9.65           1          118
# 1        1      1        316  8.00           2          104
# 2        2      2        322  8.67           3          110
# 3        3      3        314  8.21           4          103
# 4        4      4        330  9.34           5          115
#
#    University Rating  SOP  LOR  Research  Chance of Admit  CGPA_std   GRE_std  \
# 0                  4  4.5  4.5         1             0.92  1.747900  1.753381
# 1                  3  3.0  3.5         1             0.72 -0.991211 -0.063367
# 2                  3  3.5  2.5         1             0.80  0.121034  0.455704
# 3                  2  2.0  3.0         0             0.65 -0.642597 -0.236391
# 4                  5  4.5  3.0         1             0.90  1.233279  1.147798
#
#     LOR_std  deciding_column
# 0  1.191647         1.747900
# 1  0.076740        -0.991211
# 2 -1.038166         0.121034
# 3 -0.480713        -0.236391
# 4 -0.480713         1.233279

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:
admissions['decision'] = np.where(admissions['deciding_column']>0.8,1,0)
admissions.head()
# Out:
#    level_0  index  GRE Score  CGPA  Serial No.  TOEFL Score  \
# 0        0      0        337  9.65           1          118
# 1        1      1        316  8.00           2          104
# 2        2      2        322  8.67           3          110
# 3        3      3        314  8.21           4          103
# 4        4      4        330  9.34           5          115
#
#    University Rating  SOP  LOR  Research  Chance of Admit  CGPA_std   GRE_std  \
# 0                  4  4.5  4.5         1             0.92  1.747900  1.753381
# 1                  3  3.0  3.5         1             0.72 -0.991211 -0.063367
# 2                  3  3.5  2.5         1             0.80  0.121034  0.455704
# 3                  2  2.0  3.0         0             0.65 -0.642597 -0.236391
# 4                  5  4.5  3.0         1             0.90  1.233279  1.147798
#
#     LOR_std  deciding_column  decision
# 0  1.191647         1.747900         1
# 1  0.076740        -0.991211         0
# 2 -1.038166         0.121034         0
# 3 -0.480713        -0.236391         0
# 4 -0.480713         1.233279         1

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:
accepted = admissions[admissions['decision']==1].count()
accepted
# Out:
# level_0              97
# index                97
# GRE Score            97
# CGPA                 97
# Serial No.           97
# TOEFL Score          97
# University Rating    97
# SOP                  97
# LOR                  97
# Research             97
# Chance of Admit      97
# CGPA_std             97
# GRE_std              97
# LOR_std              97
# deciding_column      97
# decision             97
# dtype: int64

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# Your code here:

columnas = list(admissions.columns)

admissions = admissions.rename(columns=lambda x: x.lower().replace(" ", "_"))
admissions.head()
# Out:
#    level_0  index  gre_score  cgpa  serial_no.  toefl_score  \
# 0        0      0        337  9.65           1          118
# 1        1      1        316  8.00           2          104
# 2        2      2        322  8.67           3          110
# 3        3      3        314  8.21           4          103
# 4        4      4        330  9.34           5          115
#
#    university_rating  sop  lor  research  chance_of_admit  cgpa_std   gre_std  \
# 0                  4  4.5  4.5         1             0.92  1.747900  1.753381
# 1                  3  3.0  3.5         1             0.72 -0.991211 -0.063367
# 2                  3  3.5  2.5         1             0.80  0.121034  0.455704
# 3                  2  2.0  3.0         0             0.65 -0.642597 -0.236391
# 4                  5  4.5  3.0         1             0.90  1.233279  1.147798
#
#     lor_std  deciding_column  decision
# 0  1.191647         1.747900         1
# 1  0.076740        -0.991211         0
# 2 -1.038166         0.121034         0
# 3 -0.480713        -0.236391         0
# 4 -0.480713         1.233279         1

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:
#defino funcion que quiero lo que haga

#Preguntar octabius, lambda apply siguiente nivel

admissions.cut(, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False, duplicates='raise')[source]¶
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-5ee67895d3cc> in <module>
#       4         return col2 + 10
#       5
# ----> 6 boost(admissions, admissions['university_rating'], admissions['gre_score'])
#       7 #admissions.cut(, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False, duplicates='raise')[source]¶
#
# <ipython-input-69-5ee67895d3cc> in boost(df, col1, col2)
#       1 # Your code here:
#       2 def boost (df, col1, col2):
# ----> 3     if col1 > 4:
#       4         return col2 + 10
#       5
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
