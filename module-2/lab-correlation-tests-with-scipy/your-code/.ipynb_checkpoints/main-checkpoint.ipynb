# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# %matplotlib inline
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Analysis of Variance
#
# In this part of the lesson, we will perform an analysis of variance to determine whether the factors in our model create a significant difference in the group means. We will be examining a dataset of FIFA players. We'll start by loading the data using the code in the cell below.

# %%
# Run this code:
fifa = pd.read_csv('fifa.csv')

# %% [markdown]
# Let's examine the dataset by looking at the `head`.

# %%
# Your code here:
fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0
# 1             Juventus     €77M          Right       ST        4.0
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0
# 3    Manchester United     €72M          Right       GK        3.0
# 4      Manchester City    €102M          Right      RCM        5.0
#
#    Acceleration  SprintSpeed  Stamina  Strength  LongShots  Aggression  \
# 0          91.0         86.0     72.0      59.0       94.0        48.0
# 1          89.0         91.0     88.0      79.0       93.0        63.0
# 2          94.0         90.0     81.0      49.0       82.0        56.0
# 3          57.0         58.0     43.0      64.0       12.0        38.0
# 4          78.0         76.0     90.0      75.0       91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties
# 0           22.0         94.0    94.0       75.0
# 1           29.0         95.0    82.0       85.0
# 2           36.0         89.0    87.0       81.0
# 3           30.0         12.0    68.0       40.0
# 4           61.0         87.0    94.0       79.0

# %% [markdown]
# Player's values are expressed in millions of euros. We would like this column to be numeric. Therefore, let's create a numeric value column. Do this by stripping all non-numeric characters from each cell. Assign this new data to `ValueNumeric`. There is no need to multiply the value to be expressed in millions.

# %%
# Your code here
import re

def bring(value):
    value = re.findall('\d*\.\d|\d', value)[0]
    return float(value)

# %%
fifa['Value'] = fifa['Value'].apply(bring)
fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club  Value Preferred Foot Position  Weak Foot  \
# 0         FC Barcelona  110.5           Left       RF        4.0
# 1             Juventus    7.0          Right       ST        4.0
# 2  Paris Saint-Germain  118.5          Right       LW        5.0
# 3    Manchester United    7.0          Right       GK        3.0
# 4      Manchester City    1.0          Right      RCM        5.0
#
#    Acceleration  SprintSpeed  Stamina  Strength  LongShots  Aggression  \
# 0          91.0         86.0     72.0      59.0       94.0        48.0
# 1          89.0         91.0     88.0      79.0       93.0        63.0
# 2          94.0         90.0     81.0      49.0       82.0        56.0
# 3          57.0         58.0     43.0      64.0       12.0        38.0
# 4          78.0         76.0     90.0      75.0       91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties
# 0           22.0         94.0    94.0       75.0
# 1           29.0         95.0    82.0       85.0
# 2           36.0         89.0    87.0       81.0
# 3           30.0         12.0    68.0       40.0
# 4           61.0         87.0    94.0       79.0

# %% [markdown]
# #### We'd like to determine whether a player's preffered foot and position have an impact on their value.
#
# Using the `statsmodels` library, we are able to produce an ANOVA table without munging our data. Create an ANOVA table with value as a function of position and preferred foot. Recall that pivoting is performed by the `C` function.
#
# Hint: For columns that have a space in their name, it is best to refer to the column using the dataframe (For example: for column `A`, we will use `df['A']`).

# %%
fifa['Preferred_Foot'] = fifa['Preferred Foot']

# %%
# Your code here:
import statsmodels.api as sm
from statsmodels.formula.api import ols


model = ols('Value ~ Preferred_Foot + Position + Potential + Age', data=fifa).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                        sum_sq       df            F        PR(>F)
# Preferred_Foot       1.423767      1.0     0.092396  7.611560e-01
# Position          1474.694477     26.0     3.680822  7.073109e-10
# Potential        24444.001523      1.0  1586.311236  0.000000e+00
# Age               2713.845168      1.0   176.116954  5.249034e-40
# Residual        279170.925311  18117.0          NaN           NaN

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Value   R-squared:                       0.090
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     62.14
# Date:                Mon, 29 Jul 2019   Prob (F-statistic):               0.00
# Time:                        21:38:12   Log-Likelihood:                -50550.
# No. Observations:               18147   AIC:                         1.012e+05
# Df Residuals:                   18117   BIC:                         1.014e+05
# Df Model:                          29
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                 -12.1494      0.459    -26.453      0.000     -13.050     -11.249
# Preferred_Foot[T.Right]    -0.0242      0.080     -0.304      0.761      -0.181       0.132
# Position[T.CB]             -0.1396      0.158     -0.886      0.376      -0.449       0.169
# Position[T.CDM]             0.0138      0.180      0.077      0.939      -0.339       0.367
# Position[T.CF]              0.5037      0.474      1.063      0.288      -0.425       1.432
# Position[T.CM]              0.1058      0.165      0.640      0.522      -0.218       0.430
# Position[T.GK]             -0.1974      0.155     -1.272      0.203      -0.502       0.107
# Position[T.LAM]             2.0410      0.867      2.355      0.019       0.342       3.740
# Position[T.LB]             -0.0589      0.174     -0.338      0.735      -0.400       0.282
# Position[T.LCB]            -0.1416      0.201     -0.706      0.480      -0.535       0.252
# Position[T.LCM]             0.7629      0.235      3.247      0.001       0.302       1.223
# Position[T.LDM]             0.0279      0.282      0.099      0.921      -0.526       0.581
# Position[T.LF]              1.5153      1.022      1.483      0.138      -0.488       3.518
# Position[T.LM]              0.0921      0.174      0.530      0.596      -0.249       0.433
# Position[T.LS]              0.1247      0.301      0.414      0.679      -0.466       0.715
# Position[T.LW]              0.4591      0.238      1.930      0.054      -0.007       0.925
# Position[T.LWB]            -0.1429      0.465     -0.307      0.758      -1.054       0.768
# Position[T.RAM]             1.3768      0.866      1.589      0.112      -0.322       3.075
# Position[T.RB]              0.0163      0.169      0.097      0.923      -0.315       0.347
# Position[T.RCB]            -0.2584      0.200     -1.293      0.196      -0.650       0.133
# Position[T.RCM]             0.4177      0.236      1.769      0.077      -0.045       0.881
# Position[T.RDM]            -0.1066      0.280     -0.380      0.704      -0.656       0.443
# Position[T.RF]              5.6308      0.990      5.688      0.000       3.690       7.571
# Position[T.RM]              0.3364      0.173      1.947      0.051      -0.002       0.675
# Position[T.RS]              0.3078      0.304      1.014      0.311      -0.287       0.903
# Position[T.RW]              0.4638      0.240      1.930      0.054      -0.007       0.935
# Position[T.RWB]             0.4240      0.440      0.963      0.335      -0.439       1.287
# Position[T.ST]              0.1154      0.153      0.755      0.451      -0.184       0.415
# Potential                   0.1988      0.005     39.829      0.000       0.189       0.209
# Age                         0.0879      0.007     13.271      0.000       0.075       0.101
# ==============================================================================
# Omnibus:                    22649.926   Durbin-Watson:                   1.446
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8644068.552
# Skew:                           6.477   Prob(JB):                         0.00
# Kurtosis:                     109.133   Cond. No.                     2.69e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# Your conclusions here:

# %% [markdown]
# After looking at a model of both preffered foot and position, we decide to create an ANOVA table for nationality. Create an ANOVA table for numeric value as a function of nationality.

# %%
# Your code here:

# %% [markdown]
# What is your conclusion from this ANOVA?

# %% [markdown]
# # Challenge 2 - Linear Regression
#
# Our goal with using linear regression is to create a mathematical model that will enable us to predict the outcome of one variable using one or more additional independent variables.
#
# We'll start by ensuring there are no missing values. Examine all variables for all missing values. If there are missing values in a row, remove the entire row.

# %%
# Your code here:

# %% [markdown]
# Using the FIFA dataset, in the cell below, create a linear model predicting value using stamina and sprint speed. create the model using `statsmodels`. Print the model summary.
#
# Hint: remember to add an intercept to the model using the `add_constant` function.

# %%
# Your code here:

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:

# %% [markdown]
# Next, create a second regression model predicting value using potential. Create the model using `statsmodels` and print the model summary. Remember to add a constant term.

# %%
# Your code here:

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:

# %% [markdown]
# Plot a scatter plot of value vs. potential. Do you see a linear relationship?

# %%
# Your code here:
